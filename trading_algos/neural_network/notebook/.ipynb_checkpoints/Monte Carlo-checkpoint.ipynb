# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from alpha_vantage.timeseries import TimeSeries 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from datetime import datetime,timedelta
from dateutil.relativedelta import relativedelta
import pandas_market_calendars as mcal
import os
import yaml

os.chdir("../scripts")
import preprocess, train, inference, interpret

# %% [markdown]
# ### Note that only 5% of the data is used for validation as we are concerned with short term predictions

# %%
config = {
    "alpha_vantage": {
        "key": "2JMCN347HZ3BU9RC", 
        "symbol": "SPY",
        "outputsize": "full",
        "key_adjusted_close": "5. adjusted close",
    },
    "data": {
        "window_size": 20,
        "train_split_size": 0.95,
    }, 
    "plots": {
        "xticks_interval": 90, # show a date every 90 days
        "color_actual": "#001f3f",
        "color_train": "#3D9970",
        "color_val": "#0074D9",
        "color_pred_train": "#3D9970",
        "color_pred_val": "#0074D9",
        "color_pred_test": "#FF4136",
    },
    "model": {
        "input_size": 1, # since for now we are only using close price
        "num_lstm_layers": 2,
        "lstm_size": 32,
        "dropout": 0.2,
    },
    "training": {
        "device": "cpu",
        "batch_size": 64,
        "num_epoch": 100,
        "learning_rate": 0.01,
        "scheduler_step_size": 40,
    }
}

# %%
with open("../model/params.yaml", "r") as params_file:
    params = yaml.safe_load(params_file)

data_dir = params['data_dir']
file_name = "SPY.csv"
data = preprocess.load_data(file_name)
data.columns = data.columns.str.capitalize()
data.tail()
# Out:
#             Date     Open   Close     Low    High       Volume
# 5882  2023-03-20  390.800  393.74  390.07  394.17   93055783.0
# 5883  2023-03-21  397.240  398.91  395.58  399.41   91524248.0
# 5884  2023-03-22  398.730  392.11  392.07  402.49  111746583.0
# 5885  2023-03-23  395.090  393.17  390.35  399.29  119351319.0
# 5886  2023-03-24  391.841  395.75  389.40  395.84  107770124.0

# %%
# amount of simulations and early stop amount

n = 100
stop = 10

# %% [markdown]
# ### Univariate model

# %%
# get data for univariate time series model 

num_data_points = len(data.index)
date_data = data['Date'].to_numpy()
display_date_range = "from " + date_data[0] + " to " + date_data[num_data_points-1]
close_price_data = data['Close'].to_numpy()
close_price_data
# Out:
# array([ 88.21718508,  87.58674188,  88.17651326, ..., 392.11      ,
#        393.17      , 395.75      ])

# %%
# necessary classes for univariate model

class Normalization():
    def __init__(self):
        self.mu = None
        self.sd = None

    def fit_transform(self, x):
        self.mu = np.mean(x, axis=(0), keepdims=True)
        self.sd = np.std(x, axis=(0), keepdims=True)
        normalized_x = (x - self.mu)/self.sd
        return normalized_x

    def inverse_transform(self, x):
        return (x*self.sd) + self.mu
    
def prepare_data_x(x, window_size):
    # perform windowing
    n_row = x.shape[0] - window_size + 1
    output = np.lib.stride_tricks.as_strided(x, shape=(n_row, window_size), strides=(x.strides[0], x.strides[0]))
    return output[:-1], output[-1]


def prepare_data_y(x, window_size):
    # use the next day as label
    output = x[window_size:]
    return output

class TimeSeriesDataset(Dataset):
    def __init__(self, x, y):
        x = np.expand_dims(x, 2) # right now we have only 1 feature, so we need to convert `x` into [batch, sequence, features]
        self.x = x.astype(np.float32)
        self.y = y.astype(np.float32)
        
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return (self.x[idx], self.y[idx])
    
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_layer_size=32, num_layers=2, output_size=1, dropout=0.2):
        super().__init__()
        self.hidden_layer_size = hidden_layer_size

        self.linear_1 = nn.Linear(input_size, hidden_layer_size)
        self.relu = nn.ReLU()
        self.lstm = nn.LSTM(hidden_layer_size, hidden_size=self.hidden_layer_size, num_layers=num_layers, batch_first=True)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(num_layers*hidden_layer_size, output_size)
        
        self.init_weights()

    def init_weights(self):
        for name, param in self.lstm.named_parameters():
            if 'bias' in name:
                 nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                 nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                 nn.init.orthogonal_(param)

    def forward(self, x):
        batchsize = x.shape[0]

        # layer 1
        x = self.linear_1(x)
        x = self.relu(x)
        
        # LSTM layer
        lstm_out, (h_n, c_n) = self.lstm(x)

        # reshape output from hidden cell into [batch, features] for `linear_2`
        x = h_n.permute(1, 0, 2).reshape(batchsize, -1) 
        
        # layer 2
        x = self.dropout(x)
        predictions = self.linear_2(x)
        return predictions[:,-1]
    
def run_epoch(dataloader, is_training=False):
    epoch_loss = 0

    if is_training:
        model.train()
    else:
        model.eval()

    for idx, (x, y) in enumerate(dataloader):
        if is_training:
            optimizer.zero_grad()

        batchsize = x.shape[0]

        x = x.to(config["training"]["device"])
        y = y.to(config["training"]["device"])

        out = model(x)
        loss = criterion(out.contiguous(), y.contiguous())

        if is_training:
            loss.backward()
            optimizer.step()

        epoch_loss += (loss.detach().item() / batchsize)

    lr = scheduler.get_last_lr()[0]

    return epoch_loss, lr

# %%
# prerequisite data manipulation

scaler = Normalization()
normalized_close_price_data = scaler.fit_transform(close_price_data)
normalized_close_price_data

data_x, data_x_unseen = prepare_data_x(normalized_close_price_data, window_size=config["data"]["window_size"])
data_y = prepare_data_y(normalized_close_price_data, window_size=config["data"]["window_size"])

split_index = int(data_y.shape[0]*config["data"]["train_split_size"])
data_x_train = data_x[:split_index]
data_x_val = data_x[split_index:]
data_y_train = data_y[:split_index]
data_y_val = data_y[split_index:]

train_dataset = TimeSeriesDataset(data_x_train, data_y_train)
val_dataset = TimeSeriesDataset(data_x_val, data_y_val)

print("Train data shape", train_dataset.x.shape, train_dataset.y.shape)
print("Validation data shape", val_dataset.x.shape, val_dataset.y.shape)

train_dataloader = DataLoader(train_dataset, batch_size=config["training"]["batch_size"], shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=config["training"]["batch_size"], shuffle=True)
# Out:
# Train data shape (5573, 20, 1) (5573,)
# Validation data shape (294, 20, 1) (294,)

# %%
# Univariate Monte Carlo, no early stopping

uni_absolute = []
uni_root = []

for i in range(n):
    train_dataloader = DataLoader(train_dataset, batch_size=config["training"]["batch_size"], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=config["training"]["batch_size"], shuffle=True)

    model = LSTMModel(input_size=config["model"]["input_size"], hidden_layer_size=config["model"]["lstm_size"], num_layers=config["model"]["num_lstm_layers"], output_size=1, dropout=config["model"]["dropout"])
    model = model.to(config["training"]["device"])

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=config["training"]["learning_rate"], betas=(0.9, 0.98), eps=1e-9)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=config["training"]["scheduler_step_size"], gamma=0.1)

    for epoch in range(config["training"]["num_epoch"]):
        loss_train, lr_train = run_epoch(train_dataloader, is_training=True)
        loss_val, lr_val = run_epoch(val_dataloader)
        scheduler.step()

        print('Epoch[{}/{}] | loss train:{:.6f}, test:{:.6f} | lr:{:.6f}'
                  .format(epoch+1, config["training"]["num_epoch"], loss_train, loss_val, lr_train))
        
    train_dataloader = DataLoader(train_dataset, batch_size=config["training"]["batch_size"], shuffle=False)
    val_dataloader = DataLoader(val_dataset, batch_size=config["training"]["batch_size"], shuffle=False)

    model.eval()
    
    predicted_train = np.array([])

    for idx, (x, y) in enumerate(train_dataloader):
        x = x.to(config["training"]["device"])
        out = model(x)
        out = out.cpu().detach().numpy()
        predicted_train = np.concatenate((predicted_train, out))

    predicted_val = np.array([])

    for idx, (x, y) in enumerate(val_dataloader):
        x = x.to(config["training"]["device"])
        out = model(x)
        out = out.cpu().detach().numpy()
        predicted_val = np.concatenate((predicted_val, out))

    data_y_train_pred = np.zeros(num_data_points)
    data_y_val_pred = np.zeros(num_data_points)

    data_y_train_pred[config["data"]["window_size"]:split_index+config["data"]["window_size"]] = scaler.inverse_transform(predicted_train)
    data_y_val_pred[split_index+config["data"]["window_size"]:] = scaler.inverse_transform(predicted_val)

    mae = mean_absolute_error(close_price_data, data_y_train_pred + data_y_val_pred)
    print("Mean absolute error: ", mae)

    rmse = np.sqrt(mean_squared_error(close_price_data, data_y_train_pred+data_y_val_pred))
    print("Root mean squared error: ", rmse)
    
    uni_absolute.append(mae)
    uni_root.append(rmse)
# Out:
# Epoch[1/100] | loss train:0.056185, test:0.000697 | lr:0.010000
# Epoch[2/100] | loss train:0.017244, test:0.001826 | lr:0.010000
# Epoch[3/100] | loss train:0.011723, test:0.002435 | lr:0.010000
# Epoch[4/100] | loss train:0.009937, test:0.002854 | lr:0.010000
# Epoch[5/100] | loss train:0.008636, test:0.000487 | lr:0.010000
# Epoch[6/100] | loss train:0.009493, test:0.006761 | lr:0.010000
# Epoch[7/100] | loss train:0.009322, test:0.004907 | lr:0.010000
# Epoch[8/100] | loss train:0.010680, test:0.001069 | lr:0.010000
# Epoch[9/100] | loss train:0.008776, test:0.000548 | lr:0.010000
# Epoch[10/100] | loss train:0.007226, test:0.000367 | lr:0.010000
# Epoch[11/100] | loss train:0.017719, test:0.002548 | lr:0.010000
# Epoch[12/100] | loss train:0.011890, test:0.002271 | lr:0.010000
# Epoch[13/100] | loss train:0.008362, test:0.000788 | lr:0.010000
# Epoch[14/100] | loss train:0.008358, test:0.000606 | lr:0.010000
# Epoch[15/100] | loss train:0.007956, test:0.002565 | lr:0.010000
# Epoch[16/100] | loss train:0.007602, test:0.000561 | lr:0.010000
# Epoch[17/100] | loss train:0.009442, test:0.000482 | lr:0.010000
# Epoch[18/100] | loss train:0.007875, test:0.005895 | lr:0.010000
# Epoch[19/100] | loss train:0.006930, test:0.004474 | lr:0.010000
# Epoch[20/100] | loss train:0.008818, test:0.001169 | lr:0.010000
# Epoch[21/100] | loss train:0.007673, test:0.000507 | lr:0.010000
# Epoch[22/100] | loss train:0.008611, test:0.000655 | lr:0.010000
# Epoch[23/100] | loss train:0.011169, test:0.000589 | lr:0.010000
# Epoch[24/100] | loss train:0.008682, test:0.001086 | lr:0.010000
# Epoch[25/100] | loss train:0.007721, test:0.000653 | lr:0.010000
# Epoch[26/100] | loss train:0.008099, test:0.001951 | lr:0.010000
# Epoch[27/100] | loss train:0.006888, test:0.004704 | lr:0.010000
# Epoch[28/100] | loss train:0.008971, test:0.002810 | lr:0.010000
# Epoch[29/100] | loss train:0.008427, test:0.000378 | lr:0.010000
# Epoch[30/100] | loss train:0.007342, test:0.000649 | lr:0.010000
# Epoch[31/100] | loss train:0.007124, test:0.000804 | lr:0.010000
# Epoch[32/100] | loss train:0.007556, test:0.000394 | lr:0.010000
# Epoch[33/100] | loss train:0.006429, test:0.001127 | lr:0.010000
# Epoch[34/100] | loss train:0.006354, test:0.000454 | lr:0.010000
# Epoch[35/100] | loss train:0.007463, test:0.000494 | lr:0.010000
# Epoch[36/100] | loss train:0.007744, test:0.001935 | lr:0.010000
# Epoch[37/100] | loss train:0.007596, test:0.001113 | lr:0.010000
# Epoch[38/100] | loss train:0.007953, test:0.001554 | lr:0.010000
# Epoch[39/100] | loss train:0.008581, test:0.000399 | lr:0.010000
# Epoch[40/100] | loss train:0.006382, test:0.001017 | lr:0.010000
# Epoch[41/100] | loss train:0.005398, test:0.000374 | lr:0.001000
# Epoch[42/100] | loss train:0.005703, test:0.000409 | lr:0.001000
# Epoch[43/100] | loss train:0.006370, test:0.000471 | lr:0.001000
# Epoch[44/100] | loss train:0.005114, test:0.000414 | lr:0.001000
# Epoch[45/100] | loss train:0.005162, test:0.000418 | lr:0.001000
# Epoch[46/100] | loss train:0.005288, test:0.000514 | lr:0.001000
# Epoch[47/100] | loss train:0.006247, test:0.000365 | lr:0.001000
# Epoch[48/100] | loss train:0.005433, test:0.000412 | lr:0.001000
# Epoch[49/100] | loss train:0.005131, test:0.000354 | lr:0.001000
# Epoch[50/100] | loss train:0.005147, test:0.000351 | lr:0.001000
# Epoch[51/100] | loss train:0.005668, test:0.000376 | lr:0.001000
# Epoch[52/100] | loss train:0.004602, test:0.000337 | lr:0.001000
# Epoch[53/100] | loss train:0.005228, test:0.000383 | lr:0.001000
# Epoch[54/100] | loss train:0.005503, test:0.000336 | lr:0.001000
# Epoch[55/100] | loss train:0.005045, test:0.000485 | lr:0.001000
# Epoch[56/100] | loss train:0.005049, test:0.000340 | lr:0.001000
# Epoch[57/100] | loss train:0.005484, test:0.000327 | lr:0.001000
# Epoch[58/100] | loss train:0.004976, test:0.000376 | lr:0.001000
# Epoch[59/100] | loss train:0.005305, test:0.000361 | lr:0.001000
# Epoch[60/100] | loss train:0.005815, test:0.000352 | lr:0.001000
# Epoch[61/100] | loss train:0.005165, test:0.000684 | lr:0.001000
# Epoch[62/100] | loss train:0.005243, test:0.000316 | lr:0.001000
# Epoch[63/100] | loss train:0.006273, test:0.000407 | lr:0.001000
# Epoch[64/100] | loss train:0.005522, test:0.000336 | lr:0.001000
# Epoch[65/100] | loss train:0.005020, test:0.000424 | lr:0.001000
# Epoch[66/100] | loss train:0.005249, test:0.000331 | lr:0.001000
# Epoch[67/100] | loss train:0.004744, test:0.000317 | lr:0.001000
# Epoch[68/100] | loss train:0.006032, test:0.000474 | lr:0.001000
# Epoch[69/100] | loss train:0.004726, test:0.000324 | lr:0.001000
# Epoch[70/100] | loss train:0.005296, test:0.000305 | lr:0.001000
# Epoch[71/100] | loss train:0.005382, test:0.000311 | lr:0.001000
# Epoch[72/100] | loss train:0.004937, test:0.000491 | lr:0.001000
# Epoch[73/100] | loss train:0.007895, test:0.000458 | lr:0.001000
# Epoch[74/100] | loss train:0.005478, test:0.000309 | lr:0.001000
# Epoch[75/100] | loss train:0.005546, test:0.000466 | lr:0.001000
# Epoch[76/100] | loss train:0.006636, test:0.000387 | lr:0.001000
# Epoch[77/100] | loss train:0.004813, test:0.000627 | lr:0.001000
# Epoch[78/100] | loss train:0.005657, test:0.000318 | lr:0.001000
# Epoch[79/100] | loss train:0.005409, test:0.000318 | lr:0.001000
# Epoch[80/100] | loss train:0.004783, test:0.000371 | lr:0.001000
# Epoch[81/100] | loss train:0.004956, test:0.000370 | lr:0.000100
# Epoch[82/100] | loss train:0.005114, test:0.000337 | lr:0.000100
# Epoch[83/100] | loss train:0.006568, test:0.000310 | lr:0.000100
# Epoch[84/100] | loss train:0.005078, test:0.000339 | lr:0.000100
# Epoch[85/100] | loss train:0.004738, test:0.000313 | lr:0.000100
# Epoch[86/100] | loss train:0.004917, test:0.000308 | lr:0.000100
# Epoch[87/100] | loss train:0.005288, test:0.000342 | lr:0.000100
# Epoch[88/100] | loss train:0.005498, test:0.000309 | lr:0.000100
# Epoch[89/100] | loss train:0.004728, test:0.000310 | lr:0.000100
# Epoch[90/100] | loss train:0.004953, test:0.000336 | lr:0.000100
# Epoch[91/100] | loss train:0.005158, test:0.000304 | lr:0.000100
# Epoch[92/100] | loss train:0.005257, test:0.000314 | lr:0.000100
# Epoch[93/100] | loss train:0.005060, test:0.000330 | lr:0.000100
# Epoch[94/100] | loss train:0.005554, test:0.000297 | lr:0.000100
# Epoch[95/100] | loss train:0.005875, test:0.000302 | lr:0.000100
# Epoch[96/100] | loss train:0.005173, test:0.000324 | lr:0.000100
# Epoch[97/100] | loss train:0.005039, test:0.000351 | lr:0.000100
# Epoch[98/100] | loss train:0.005346, test:0.000304 | lr:0.000100
# Epoch[99/100] | loss train:0.004707, test:0.000299 | lr:0.000100
# Epoch[100/100] | loss train:0.005032, test:0.000301 | lr:0.000100
# Mean absolute error:  1.680541260422634
# Root mean squared error:  5.788014671595079
# Epoch[1/100] | loss train:0.055194, test:0.000395 | lr:0.010000
# Epoch[2/100] | loss train:0.011145, test:0.001194 | lr:0.010000
# Epoch[3/100] | loss train:0.011028, test:0.004699 | lr:0.010000
# Epoch[4/100] | loss train:0.010610, test:0.000533 | lr:0.010000
# Epoch[5/100] | loss train:0.010957, test:0.002244 | lr:0.010000
# Epoch[6/100] | loss train:0.009339, test:0.002144 | lr:0.010000
# Epoch[7/100] | loss train:0.008500, test:0.001390 | lr:0.010000
# Epoch[8/100] | loss train:0.008612, test:0.000404 | lr:0.010000
# Epoch[9/100] | loss train:0.008420, test:0.000292 | lr:0.010000
# Epoch[10/100] | loss train:0.008184, test:0.000391 | lr:0.010000
# Epoch[11/100] | loss train:0.010709, test:0.000572 | lr:0.010000
# Epoch[12/100] | loss train:0.009116, test:0.001801 | lr:0.010000
# Epoch[13/100] | loss train:0.008663, test:0.002649 | lr:0.010000
# Epoch[14/100] | loss train:0.008378, test:0.001002 | lr:0.010000
# Epoch[15/100] | loss train:0.008457, test:0.001750 | lr:0.010000
# Epoch[16/100] | loss train:0.009986, test:0.001085 | lr:0.010000
# Epoch[17/100] | loss train:0.007735, test:0.000399 | lr:0.010000
# Epoch[18/100] | loss train:0.007461, test:0.000915 | lr:0.010000
# Epoch[19/100] | loss train:0.008290, test:0.000922 | lr:0.010000
# Epoch[20/100] | loss train:0.009697, test:0.000940 | lr:0.010000
# Epoch[21/100] | loss train:0.010296, test:0.000349 | lr:0.010000
# Epoch[22/100] | loss train:0.007063, test:0.000681 | lr:0.010000
# Epoch[23/100] | loss train:0.007311, test:0.000495 | lr:0.010000
# Epoch[24/100] | loss train:0.007083, test:0.000624 | lr:0.010000
# Epoch[25/100] | loss train:0.006512, test:0.000422 | lr:0.010000
# Epoch[26/100] | loss train:0.007247, test:0.001089 | lr:0.010000
# Epoch[27/100] | loss train:0.008152, test:0.000465 | lr:0.010000
# Epoch[28/100] | loss train:0.008800, test:0.003001 | lr:0.010000
# Epoch[29/100] | loss train:0.011530, test:0.000832 | lr:0.010000
# Epoch[30/100] | loss train:0.007515, test:0.001473 | lr:0.010000
# Epoch[31/100] | loss train:0.007788, test:0.000473 | lr:0.010000
# Epoch[32/100] | loss train:0.007760, test:0.001568 | lr:0.010000
# Epoch[33/100] | loss train:0.007594, test:0.001398 | lr:0.010000
# Epoch[34/100] | loss train:0.007050, test:0.001180 | lr:0.010000
# Epoch[35/100] | loss train:0.007067, test:0.000361 | lr:0.010000
# Epoch[36/100] | loss train:0.007060, test:0.000577 | lr:0.010000
# Epoch[37/100] | loss train:0.006270, test:0.002013 | lr:0.010000
# Epoch[38/100] | loss train:0.009895, test:0.000858 | lr:0.010000
# Epoch[39/100] | loss train:0.008708, test:0.000492 | lr:0.010000
# Epoch[40/100] | loss train:0.009557, test:0.002428 | lr:0.010000
# Epoch[41/100] | loss train:0.007090, test:0.000494 | lr:0.001000
# Epoch[42/100] | loss train:0.005619, test:0.000358 | lr:0.001000
# Epoch[43/100] | loss train:0.007078, test:0.000381 | lr:0.001000
# Epoch[44/100] | loss train:0.005778, test:0.000433 | lr:0.001000
# Epoch[45/100] | loss train:0.005220, test:0.000442 | lr:0.001000
# Epoch[46/100] | loss train:0.005425, test:0.000372 | lr:0.001000
# Epoch[47/100] | loss train:0.005328, test:0.000350 | lr:0.001000
# Epoch[48/100] | loss train:0.005113, test:0.000373 | lr:0.001000
# Epoch[49/100] | loss train:0.005588, test:0.000373 | lr:0.001000
# Epoch[50/100] | loss train:0.006855, test:0.000372 | lr:0.001000
# Epoch[51/100] | loss train:0.005576, test:0.000412 | lr:0.001000
# Epoch[52/100] | loss train:0.007081, test:0.000634 | lr:0.001000
# Epoch[53/100] | loss train:0.005692, test:0.000356 | lr:0.001000
# Epoch[54/100] | loss train:0.005294, test:0.000354 | lr:0.001000
# Epoch[55/100] | loss train:0.005450, test:0.000365 | lr:0.001000
# Epoch[56/100] | loss train:0.006597, test:0.000620 | lr:0.001000
# Epoch[57/100] | loss train:0.008833, test:0.000746 | lr:0.001000
# Epoch[58/100] | loss train:0.006158, test:0.000453 | lr:0.001000
# Epoch[59/100] | loss train:0.005421, test:0.000375 | lr:0.001000
# Epoch[60/100] | loss train:0.011249, test:0.000401 | lr:0.001000
# Epoch[61/100] | loss train:0.006301, test:0.000427 | lr:0.001000
# Epoch[62/100] | loss train:0.005537, test:0.000332 | lr:0.001000
# Epoch[63/100] | loss train:0.005580, test:0.000351 | lr:0.001000
# Epoch[64/100] | loss train:0.005089, test:0.000403 | lr:0.001000
# Epoch[65/100] | loss train:0.005147, test:0.000363 | lr:0.001000
# Epoch[66/100] | loss train:0.004997, test:0.000389 | lr:0.001000
# Epoch[67/100] | loss train:0.005901, test:0.000480 | lr:0.001000
# Epoch[68/100] | loss train:0.006293, test:0.000706 | lr:0.001000
# Epoch[69/100] | loss train:0.005530, test:0.000512 | lr:0.001000
# Epoch[70/100] | loss train:0.004889, test:0.000567 | lr:0.001000
# Epoch[71/100] | loss train:0.007140, test:0.000341 | lr:0.001000
# Epoch[72/100] | loss train:0.007301, test:0.000585 | lr:0.001000
# Epoch[73/100] | loss train:0.004817, test:0.000316 | lr:0.001000
# Epoch[74/100] | loss train:0.007082, test:0.000428 | lr:0.001000
# Epoch[75/100] | loss train:0.005316, test:0.000382 | lr:0.001000
# Epoch[76/100] | loss train:0.007413, test:0.000481 | lr:0.001000
# Epoch[77/100] | loss train:0.005349, test:0.000440 | lr:0.001000
# Epoch[78/100] | loss train:0.005750, test:0.000375 | lr:0.001000
# Epoch[79/100] | loss train:0.004952, test:0.000363 | lr:0.001000
# Epoch[80/100] | loss train:0.005056, test:0.000346 | lr:0.001000
# Epoch[81/100] | loss train:0.004603, test:0.000320 | lr:0.000100
# Epoch[82/100] | loss train:0.004977, test:0.000321 | lr:0.000100
# Epoch[83/100] | loss train:0.005065, test:0.000302 | lr:0.000100
# Epoch[84/100] | loss train:0.005027, test:0.000310 | lr:0.000100
# Epoch[85/100] | loss train:0.004924, test:0.000307 | lr:0.000100
# Epoch[86/100] | loss train:0.005158, test:0.000337 | lr:0.000100
# Epoch[87/100] | loss train:0.004928, test:0.000304 | lr:0.000100
# Epoch[88/100] | loss train:0.004638, test:0.000315 | lr:0.000100
# Epoch[89/100] | loss train:0.005301, test:0.000324 | lr:0.000100
# Epoch[90/100] | loss train:0.004788, test:0.000317 | lr:0.000100
# Epoch[91/100] | loss train:0.004765, test:0.000322 | lr:0.000100
# Epoch[92/100] | loss train:0.005190, test:0.000313 | lr:0.000100
# Epoch[93/100] | loss train:0.005099, test:0.000319 | lr:0.000100
# Epoch[94/100] | loss train:0.005549, test:0.000333 | lr:0.000100
# Epoch[95/100] | loss train:0.005070, test:0.000329 | lr:0.000100
# Epoch[96/100] | loss train:0.004780, test:0.000364 | lr:0.000100
# Epoch[97/100] | loss train:0.004850, test:0.000305 | lr:0.000100
# Epoch[98/100] | loss train:0.005620, test:0.000310 | lr:0.000100
# Epoch[99/100] | loss train:0.004699, test:0.000306 | lr:0.000100
# Epoch[100/100] | loss train:0.006357, test:0.000308 | lr:0.000100
# Mean absolute error:  1.6587191526553515
# Root mean squared error:  5.785349352269729
# Epoch[1/100] | loss train:0.055762, test:0.000601 | lr:0.010000
# Epoch[2/100] | loss train:0.009747, test:0.000346 | lr:0.010000
# Epoch[3/100] | loss train:0.010717, test:0.007134 | lr:0.010000
# Epoch[4/100] | loss train:0.009384, test:0.002140 | lr:0.010000
# Epoch[5/100] | loss train:0.009113, test:0.000394 | lr:0.010000
# Epoch[6/100] | loss train:0.007638, test:0.004463 | lr:0.010000
# Epoch[7/100] | loss train:0.008426, test:0.000475 | lr:0.010000
# Epoch[8/100] | loss train:0.008736, test:0.009980 | lr:0.010000
# Epoch[9/100] | loss train:0.013613, test:0.004336 | lr:0.010000
# Epoch[10/100] | loss train:0.011420, test:0.004394 | lr:0.010000
# Epoch[11/100] | loss train:0.008488, test:0.001036 | lr:0.010000
# Epoch[12/100] | loss train:0.008008, test:0.000341 | lr:0.010000
# Epoch[13/100] | loss train:0.007918, test:0.001418 | lr:0.010000
# Epoch[14/100] | loss train:0.007321, test:0.001558 | lr:0.010000
# Epoch[15/100] | loss train:0.013153, test:0.001668 | lr:0.010000
# Epoch[16/100] | loss train:0.008598, test:0.000814 | lr:0.010000
# Epoch[17/100] | loss train:0.008284, test:0.000390 | lr:0.010000
# Epoch[18/100] | loss train:0.007262, test:0.000352 | lr:0.010000
# Epoch[19/100] | loss train:0.011533, test:0.001147 | lr:0.010000
# Epoch[20/100] | loss train:0.008004, test:0.001096 | lr:0.010000
# Epoch[21/100] | loss train:0.009212, test:0.000942 | lr:0.010000
# Epoch[22/100] | loss train:0.011952, test:0.000781 | lr:0.010000
# Epoch[23/100] | loss train:0.007859, test:0.000756 | lr:0.010000
# Epoch[24/100] | loss train:0.008657, test:0.000621 | lr:0.010000
# Epoch[25/100] | loss train:0.007158, test:0.000803 | lr:0.010000
# Epoch[26/100] | loss train:0.007771, test:0.001344 | lr:0.010000
# Epoch[27/100] | loss train:0.008282, test:0.001002 | lr:0.010000
# Epoch[28/100] | loss train:0.007892, test:0.000640 | lr:0.010000
# Epoch[29/100] | loss train:0.008553, test:0.000455 | lr:0.010000
# Epoch[30/100] | loss train:0.006741, test:0.000591 | lr:0.010000
# Epoch[31/100] | loss train:0.007006, test:0.000590 | lr:0.010000
# Epoch[32/100] | loss train:0.008059, test:0.000453 | lr:0.010000
# Epoch[33/100] | loss train:0.006418, test:0.000532 | lr:0.010000
# Epoch[34/100] | loss train:0.007962, test:0.000513 | lr:0.010000
# Epoch[35/100] | loss train:0.009488, test:0.000896 | lr:0.010000
# Epoch[36/100] | loss train:0.007480, test:0.000580 | lr:0.010000
# Epoch[37/100] | loss train:0.006749, test:0.000429 | lr:0.010000
# Epoch[38/100] | loss train:0.007003, test:0.002750 | lr:0.010000
# Epoch[39/100] | loss train:0.007143, test:0.005956 | lr:0.010000
# Epoch[40/100] | loss train:0.006911, test:0.001220 | lr:0.010000
# Epoch[41/100] | loss train:0.005881, test:0.000359 | lr:0.001000
# Epoch[42/100] | loss train:0.005670, test:0.000414 | lr:0.001000
# Epoch[43/100] | loss train:0.005981, test:0.000565 | lr:0.001000
# Epoch[44/100] | loss train:0.005104, test:0.000397 | lr:0.001000
# Epoch[45/100] | loss train:0.005834, test:0.000354 | lr:0.001000
# Epoch[46/100] | loss train:0.004821, test:0.000374 | lr:0.001000
# Epoch[47/100] | loss train:0.005261, test:0.000443 | lr:0.001000
# Epoch[48/100] | loss train:0.005308, test:0.000367 | lr:0.001000
# Epoch[49/100] | loss train:0.005363, test:0.000325 | lr:0.001000
# Epoch[50/100] | loss train:0.005203, test:0.000461 | lr:0.001000
# Epoch[51/100] | loss train:0.005163, test:0.000344 | lr:0.001000
# Epoch[52/100] | loss train:0.005692, test:0.000411 | lr:0.001000
# Epoch[53/100] | loss train:0.005014, test:0.000350 | lr:0.001000
# Epoch[54/100] | loss train:0.008149, test:0.000378 | lr:0.001000
# Epoch[55/100] | loss train:0.005532, test:0.000353 | lr:0.001000
# Epoch[56/100] | loss train:0.005144, test:0.000356 | lr:0.001000
# Epoch[57/100] | loss train:0.004760, test:0.000395 | lr:0.001000
# Epoch[58/100] | loss train:0.005191, test:0.000311 | lr:0.001000
# Epoch[59/100] | loss train:0.005759, test:0.000365 | lr:0.001000
# Epoch[60/100] | loss train:0.005179, test:0.000285 | lr:0.001000
# Epoch[61/100] | loss train:0.005875, test:0.000366 | lr:0.001000
# Epoch[62/100] | loss train:0.004959, test:0.000355 | lr:0.001000
# Epoch[63/100] | loss train:0.005411, test:0.000424 | lr:0.001000
# Epoch[64/100] | loss train:0.006957, test:0.000320 | lr:0.001000
# Epoch[65/100] | loss train:0.004950, test:0.000465 | lr:0.001000
# Epoch[66/100] | loss train:0.004858, test:0.000380 | lr:0.001000
# Epoch[67/100] | loss train:0.004714, test:0.000502 | lr:0.001000
# Epoch[68/100] | loss train:0.004674, test:0.000379 | lr:0.001000
# Epoch[69/100] | loss train:0.004848, test:0.000358 | lr:0.001000
# Epoch[70/100] | loss train:0.005318, test:0.000445 | lr:0.001000
# Epoch[71/100] | loss train:0.005399, test:0.000325 | lr:0.001000
# Epoch[72/100] | loss train:0.005227, test:0.000461 | lr:0.001000
# Epoch[73/100] | loss train:0.004967, test:0.000336 | lr:0.001000
# Epoch[74/100] | loss train:0.006534, test:0.000436 | lr:0.001000
# Epoch[75/100] | loss train:0.005985, test:0.000385 | lr:0.001000
# Epoch[76/100] | loss train:0.004837, test:0.000309 | lr:0.001000
# Epoch[77/100] | loss train:0.008468, test:0.000643 | lr:0.001000
# Epoch[78/100] | loss train:0.005270, test:0.000435 | lr:0.001000
# Epoch[79/100] | loss train:0.005274, test:0.000337 | lr:0.001000
# Epoch[80/100] | loss train:0.004793, test:0.000305 | lr:0.001000
# Epoch[81/100] | loss train:0.005637, test:0.000330 | lr:0.000100
# Epoch[82/100] | loss train:0.007189, test:0.000304 | lr:0.000100
# Epoch[83/100] | loss train:0.007183, test:0.000304 | lr:0.000100
# Epoch[84/100] | loss train:0.004915, test:0.000316 | lr:0.000100
# Epoch[85/100] | loss train:0.004832, test:0.000338 | lr:0.000100
# Epoch[86/100] | loss train:0.005278, test:0.000327 | lr:0.000100
# Epoch[87/100] | loss train:0.006041, test:0.000292 | lr:0.000100
# Epoch[88/100] | loss train:0.005211, test:0.000307 | lr:0.000100
# Epoch[89/100] | loss train:0.004805, test:0.000309 | lr:0.000100
# Epoch[90/100] | loss train:0.004966, test:0.000320 | lr:0.000100
# Epoch[91/100] | loss train:0.005596, test:0.000337 | lr:0.000100
# Epoch[92/100] | loss train:0.005377, test:0.000351 | lr:0.000100
# Epoch[93/100] | loss train:0.005599, test:0.000321 | lr:0.000100
# Epoch[94/100] | loss train:0.004368, test:0.000319 | lr:0.000100
# Epoch[95/100] | loss train:0.005782, test:0.000326 | lr:0.000100
# Epoch[96/100] | loss train:0.004702, test:0.000324 | lr:0.000100
# Epoch[97/100] | loss train:0.005020, test:0.000323 | lr:0.000100
# Epoch[98/100] | loss train:0.004962, test:0.000291 | lr:0.000100
# Epoch[99/100] | loss train:0.004590, test:0.000352 | lr:0.000100
# Epoch[100/100] | loss train:0.005264, test:0.000342 | lr:0.000100
# Mean absolute error:  1.7381535411615596
# Root mean squared error:  5.82533001558238
# Epoch[1/100] | loss train:0.060959, test:0.000645 | lr:0.010000
# Epoch[2/100] | loss train:0.013929, test:0.005510 | lr:0.010000
# Epoch[3/100] | loss train:0.012919, test:0.009785 | lr:0.010000
# Epoch[4/100] | loss train:0.015275, test:0.000497 | lr:0.010000
# Epoch[5/100] | loss train:0.011045, test:0.001030 | lr:0.010000
# Epoch[6/100] | loss train:0.008287, test:0.000912 | lr:0.010000
# Epoch[7/100] | loss train:0.009418, test:0.003629 | lr:0.010000
# Epoch[8/100] | loss train:0.009095, test:0.000493 | lr:0.010000
# Epoch[9/100] | loss train:0.008292, test:0.004962 | lr:0.010000
# Epoch[10/100] | loss train:0.009723, test:0.000397 | lr:0.010000
# Epoch[11/100] | loss train:0.007832, test:0.002023 | lr:0.010000
# Epoch[12/100] | loss train:0.007854, test:0.000358 | lr:0.010000
# Epoch[13/100] | loss train:0.008951, test:0.001326 | lr:0.010000
# Epoch[14/100] | loss train:0.008499, test:0.000412 | lr:0.010000
# Epoch[15/100] | loss train:0.008165, test:0.001020 | lr:0.010000
# Epoch[16/100] | loss train:0.007724, test:0.001017 | lr:0.010000
# Epoch[17/100] | loss train:0.010567, test:0.000387 | lr:0.010000
# Epoch[18/100] | loss train:0.007614, test:0.000471 | lr:0.010000
# Epoch[19/100] | loss train:0.006993, test:0.002612 | lr:0.010000
# Epoch[20/100] | loss train:0.007555, test:0.003362 | lr:0.010000
# Epoch[21/100] | loss train:0.010962, test:0.000761 | lr:0.010000
# Epoch[22/100] | loss train:0.008480, test:0.000448 | lr:0.010000
# Epoch[23/100] | loss train:0.009052, test:0.001164 | lr:0.010000
# Epoch[24/100] | loss train:0.007019, test:0.000793 | lr:0.010000
# Epoch[25/100] | loss train:0.007612, test:0.000384 | lr:0.010000
# Epoch[26/100] | loss train:0.010235, test:0.005699 | lr:0.010000
# Epoch[27/100] | loss train:0.008197, test:0.001160 | lr:0.010000
# Epoch[28/100] | loss train:0.009186, test:0.001473 | lr:0.010000
# Epoch[29/100] | loss train:0.008804, test:0.000958 | lr:0.010000
# Epoch[30/100] | loss train:0.006944, test:0.000503 | lr:0.010000
# Epoch[31/100] | loss train:0.010508, test:0.001378 | lr:0.010000
# Epoch[32/100] | loss train:0.008711, test:0.000661 | lr:0.010000
# Epoch[33/100] | loss train:0.007529, test:0.000509 | lr:0.010000
# Epoch[34/100] | loss train:0.009440, test:0.000670 | lr:0.010000
# Epoch[35/100] | loss train:0.006881, test:0.001008 | lr:0.010000
# Epoch[36/100] | loss train:0.006757, test:0.000710 | lr:0.010000
# Epoch[37/100] | loss train:0.007151, test:0.001997 | lr:0.010000
# Epoch[38/100] | loss train:0.007944, test:0.003004 | lr:0.010000
# Epoch[39/100] | loss train:0.007899, test:0.000665 | lr:0.010000
# Epoch[40/100] | loss train:0.007535, test:0.000462 | lr:0.010000
# Epoch[41/100] | loss train:0.005943, test:0.000427 | lr:0.001000
# Epoch[42/100] | loss train:0.005549, test:0.000395 | lr:0.001000
# Epoch[43/100] | loss train:0.006033, test:0.000443 | lr:0.001000
# Epoch[44/100] | loss train:0.005368, test:0.000507 | lr:0.001000
# Epoch[45/100] | loss train:0.005925, test:0.000661 | lr:0.001000
# Epoch[46/100] | loss train:0.004915, test:0.000411 | lr:0.001000
# Epoch[47/100] | loss train:0.005396, test:0.000488 | lr:0.001000
# Epoch[48/100] | loss train:0.005354, test:0.000381 | lr:0.001000
# Epoch[49/100] | loss train:0.005180, test:0.000387 | lr:0.001000
# Epoch[50/100] | loss train:0.005242, test:0.000579 | lr:0.001000
# Epoch[51/100] | loss train:0.005996, test:0.000427 | lr:0.001000
# Epoch[52/100] | loss train:0.005732, test:0.000476 | lr:0.001000
# Epoch[53/100] | loss train:0.005151, test:0.000385 | lr:0.001000
# Epoch[54/100] | loss train:0.005589, test:0.000360 | lr:0.001000
# Epoch[55/100] | loss train:0.005303, test:0.000336 | lr:0.001000
# Epoch[56/100] | loss train:0.005290, test:0.000508 | lr:0.001000
# Epoch[57/100] | loss train:0.005695, test:0.000391 | lr:0.001000
# Epoch[58/100] | loss train:0.005222, test:0.000419 | lr:0.001000
# Epoch[59/100] | loss train:0.006082, test:0.000590 | lr:0.001000
# Epoch[60/100] | loss train:0.005992, test:0.000369 | lr:0.001000
# Epoch[61/100] | loss train:0.005993, test:0.000499 | lr:0.001000
# Epoch[62/100] | loss train:0.005292, test:0.000419 | lr:0.001000
# Epoch[63/100] | loss train:0.005284, test:0.000459 | lr:0.001000
# Epoch[64/100] | loss train:0.006521, test:0.000454 | lr:0.001000
# Epoch[65/100] | loss train:0.006622, test:0.000676 | lr:0.001000
# Epoch[66/100] | loss train:0.005760, test:0.000448 | lr:0.001000
# Epoch[67/100] | loss train:0.005458, test:0.000364 | lr:0.001000
# Epoch[68/100] | loss train:0.006574, test:0.000434 | lr:0.001000
# Epoch[69/100] | loss train:0.005262, test:0.000501 | lr:0.001000
# Epoch[70/100] | loss train:0.007663, test:0.000344 | lr:0.001000
# Epoch[71/100] | loss train:0.005638, test:0.000373 | lr:0.001000
# Epoch[72/100] | loss train:0.006347, test:0.000401 | lr:0.001000
# Epoch[73/100] | loss train:0.005523, test:0.000476 | lr:0.001000
# Epoch[74/100] | loss train:0.005482, test:0.000362 | lr:0.001000
# Epoch[75/100] | loss train:0.005287, test:0.000439 | lr:0.001000
# Epoch[76/100] | loss train:0.005898, test:0.000364 | lr:0.001000
# Epoch[77/100] | loss train:0.006662, test:0.000550 | lr:0.001000
# Epoch[78/100] | loss train:0.005910, test:0.000419 | lr:0.001000
# Epoch[79/100] | loss train:0.005522, test:0.000341 | lr:0.001000
# Epoch[80/100] | loss train:0.005264, test:0.000319 | lr:0.001000
# Epoch[81/100] | loss train:0.005520, test:0.000334 | lr:0.000100
# Epoch[82/100] | loss train:0.005231, test:0.000355 | lr:0.000100
# Epoch[83/100] | loss train:0.005124, test:0.000348 | lr:0.000100
# Epoch[84/100] | loss train:0.006436, test:0.000364 | lr:0.000100
# Epoch[85/100] | loss train:0.005850, test:0.000359 | lr:0.000100
# Epoch[86/100] | loss train:0.005300, test:0.000337 | lr:0.000100
# Epoch[87/100] | loss train:0.005104, test:0.000348 | lr:0.000100
# Epoch[88/100] | loss train:0.004782, test:0.000342 | lr:0.000100
# Epoch[89/100] | loss train:0.005649, test:0.000379 | lr:0.000100
# Epoch[90/100] | loss train:0.004881, test:0.000357 | lr:0.000100
# Epoch[91/100] | loss train:0.005984, test:0.000317 | lr:0.000100
# Epoch[92/100] | loss train:0.004976, test:0.000314 | lr:0.000100
# Epoch[93/100] | loss train:0.005886, test:0.000360 | lr:0.000100
# Epoch[94/100] | loss train:0.004873, test:0.000329 | lr:0.000100
# Epoch[95/100] | loss train:0.004998, test:0.000353 | lr:0.000100
# Epoch[96/100] | loss train:0.005017, test:0.000368 | lr:0.000100
# Epoch[97/100] | loss train:0.004782, test:0.000322 | lr:0.000100
# Epoch[98/100] | loss train:0.005273, test:0.000336 | lr:0.000100
# Epoch[99/100] | loss train:0.005521, test:0.000392 | lr:0.000100
# Epoch[100/100] | loss train:0.005190, test:0.000366 | lr:0.000100
# Mean absolute error:  1.714088563908829
# Root mean squared error:  5.820149914473197
# Epoch[1/100] | loss train:0.056943, test:0.002386 | lr:0.010000
# Epoch[2/100] | loss train:0.012639, test:0.003039 | lr:0.010000
# Epoch[3/100] | loss train:0.009461, test:0.001835 | lr:0.010000
# Epoch[4/100] | loss train:0.011323, test:0.001719 | lr:0.010000
# Epoch[5/100] | loss train:0.008903, test:0.001326 | lr:0.010000
# Epoch[6/100] | loss train:0.009647, test:0.000671 | lr:0.010000
# Epoch[7/100] | loss train:0.009371, test:0.000571 | lr:0.010000
# Epoch[8/100] | loss train:0.009092, test:0.008010 | lr:0.010000
# Epoch[9/100] | loss train:0.012947, test:0.001794 | lr:0.010000
# Epoch[10/100] | loss train:0.009317, test:0.001070 | lr:0.010000
# Epoch[11/100] | loss train:0.009128, test:0.001286 | lr:0.010000
# Epoch[12/100] | loss train:0.008418, test:0.004062 | lr:0.010000
# Epoch[13/100] | loss train:0.008633, test:0.000740 | lr:0.010000
# Epoch[14/100] | loss train:0.008649, test:0.000577 | lr:0.010000
# Epoch[15/100] | loss train:0.007453, test:0.002734 | lr:0.010000
# Epoch[16/100] | loss train:0.010194, test:0.000663 | lr:0.010000
# Epoch[17/100] | loss train:0.008091, test:0.001012 | lr:0.010000
# Epoch[18/100] | loss train:0.007457, test:0.000521 | lr:0.010000
# Epoch[19/100] | loss train:0.007119, test:0.000579 | lr:0.010000
# Epoch[20/100] | loss train:0.009477, test:0.001203 | lr:0.010000
# Epoch[21/100] | loss train:0.010151, test:0.004982 | lr:0.010000
# Epoch[22/100] | loss train:0.009026, test:0.009755 | lr:0.010000
# Epoch[23/100] | loss train:0.008074, test:0.000417 | lr:0.010000
# Epoch[24/100] | loss train:0.007358, test:0.001302 | lr:0.010000
# Epoch[25/100] | loss train:0.007448, test:0.000667 | lr:0.010000
# Epoch[26/100] | loss train:0.007365, test:0.000515 | lr:0.010000
# Epoch[27/100] | loss train:0.007545, test:0.001947 | lr:0.010000
# Epoch[28/100] | loss train:0.008201, test:0.000424 | lr:0.010000
# Epoch[29/100] | loss train:0.009743, test:0.000932 | lr:0.010000
# Epoch[30/100] | loss train:0.006578, test:0.001302 | lr:0.010000
# Epoch[31/100] | loss train:0.006877, test:0.002697 | lr:0.010000
# Epoch[32/100] | loss train:0.010005, test:0.001451 | lr:0.010000
# Epoch[33/100] | loss train:0.009388, test:0.002853 | lr:0.010000
# Epoch[34/100] | loss train:0.009192, test:0.000431 | lr:0.010000
# Epoch[35/100] | loss train:0.008713, test:0.000666 | lr:0.010000
# Epoch[36/100] | loss train:0.007596, test:0.000512 | lr:0.010000
# Epoch[37/100] | loss train:0.007399, test:0.000473 | lr:0.010000
# Epoch[38/100] | loss train:0.009093, test:0.000662 | lr:0.010000
# Epoch[39/100] | loss train:0.008734, test:0.001266 | lr:0.010000
# Epoch[40/100] | loss train:0.007775, test:0.000567 | lr:0.010000
# Epoch[41/100] | loss train:0.005634, test:0.000475 | lr:0.001000
# Epoch[42/100] | loss train:0.006581, test:0.000481 | lr:0.001000
# Epoch[43/100] | loss train:0.005671, test:0.000407 | lr:0.001000
# Epoch[44/100] | loss train:0.005457, test:0.000435 | lr:0.001000
# Epoch[45/100] | loss train:0.005849, test:0.000678 | lr:0.001000
# Epoch[46/100] | loss train:0.005175, test:0.000390 | lr:0.001000
# Epoch[47/100] | loss train:0.005396, test:0.000487 | lr:0.001000
# Epoch[48/100] | loss train:0.004992, test:0.000377 | lr:0.001000
# Epoch[49/100] | loss train:0.007738, test:0.000385 | lr:0.001000
# Epoch[50/100] | loss train:0.005266, test:0.000358 | lr:0.001000
# Epoch[51/100] | loss train:0.005353, test:0.000760 | lr:0.001000
# Epoch[52/100] | loss train:0.007361, test:0.000456 | lr:0.001000
# Epoch[53/100] | loss train:0.007658, test:0.000415 | lr:0.001000
# Epoch[54/100] | loss train:0.005311, test:0.000369 | lr:0.001000
# Epoch[55/100] | loss train:0.005710, test:0.000537 | lr:0.001000
# Epoch[56/100] | loss train:0.005284, test:0.000443 | lr:0.001000
# Epoch[57/100] | loss train:0.005034, test:0.000373 | lr:0.001000
# Epoch[58/100] | loss train:0.005119, test:0.000391 | lr:0.001000
# Epoch[59/100] | loss train:0.005798, test:0.000333 | lr:0.001000
# Epoch[60/100] | loss train:0.005454, test:0.000351 | lr:0.001000
# Epoch[61/100] | loss train:0.005378, test:0.000428 | lr:0.001000
# Epoch[62/100] | loss train:0.005357, test:0.000377 | lr:0.001000
# Epoch[63/100] | loss train:0.006727, test:0.000457 | lr:0.001000
# Epoch[64/100] | loss train:0.005701, test:0.000366 | lr:0.001000
# Epoch[65/100] | loss train:0.005355, test:0.000355 | lr:0.001000
# Epoch[66/100] | loss train:0.005291, test:0.000515 | lr:0.001000
# Epoch[67/100] | loss train:0.005606, test:0.000362 | lr:0.001000
# Epoch[68/100] | loss train:0.005555, test:0.000499 | lr:0.001000
# Epoch[69/100] | loss train:0.005181, test:0.000287 | lr:0.001000
# Epoch[70/100] | loss train:0.006011, test:0.000347 | lr:0.001000
# Epoch[71/100] | loss train:0.005752, test:0.000518 | lr:0.001000
# Epoch[72/100] | loss train:0.006125, test:0.000914 | lr:0.001000
# Epoch[73/100] | loss train:0.005584, test:0.000314 | lr:0.001000
# Epoch[74/100] | loss train:0.005237, test:0.000328 | lr:0.001000
# Epoch[75/100] | loss train:0.005126, test:0.000318 | lr:0.001000
# Epoch[76/100] | loss train:0.005392, test:0.000364 | lr:0.001000
# Epoch[77/100] | loss train:0.005675, test:0.000466 | lr:0.001000
# Epoch[78/100] | loss train:0.005887, test:0.000330 | lr:0.001000
# Epoch[79/100] | loss train:0.005247, test:0.000354 | lr:0.001000
# Epoch[80/100] | loss train:0.005135, test:0.000361 | lr:0.001000
# Epoch[81/100] | loss train:0.005457, test:0.000338 | lr:0.000100
# Epoch[82/100] | loss train:0.005563, test:0.000401 | lr:0.000100
# Epoch[83/100] | loss train:0.006142, test:0.000306 | lr:0.000100
# Epoch[84/100] | loss train:0.005326, test:0.000352 | lr:0.000100
# Epoch[85/100] | loss train:0.005030, test:0.000302 | lr:0.000100
# Epoch[86/100] | loss train:0.004897, test:0.000313 | lr:0.000100
# Epoch[87/100] | loss train:0.004944, test:0.000372 | lr:0.000100
# Epoch[88/100] | loss train:0.005606, test:0.000323 | lr:0.000100
# Epoch[89/100] | loss train:0.005925, test:0.000318 | lr:0.000100
# Epoch[90/100] | loss train:0.005294, test:0.000335 | lr:0.000100
# Epoch[91/100] | loss train:0.005549, test:0.000311 | lr:0.000100
# Epoch[92/100] | loss train:0.005100, test:0.000346 | lr:0.000100
# Epoch[93/100] | loss train:0.005630, test:0.000313 | lr:0.000100
# Epoch[94/100] | loss train:0.004928, test:0.000314 | lr:0.000100
# Epoch[95/100] | loss train:0.005162, test:0.000315 | lr:0.000100
# Epoch[96/100] | loss train:0.005199, test:0.000312 | lr:0.000100
# Epoch[97/100] | loss train:0.006081, test:0.000338 | lr:0.000100
# Epoch[98/100] | loss train:0.005080, test:0.000326 | lr:0.000100
# Epoch[99/100] | loss train:0.005591, test:0.000311 | lr:0.000100
# Epoch[100/100] | loss train:0.005816, test:0.000333 | lr:0.000100
# Mean absolute error:  1.6815280925319227
# Root mean squared error:  5.794097373819751
# Epoch[1/100] | loss train:0.066522, test:0.000581 | lr:0.010000
# Epoch[2/100] | loss train:0.011043, test:0.000891 | lr:0.010000
# Epoch[3/100] | loss train:0.013722, test:0.001049 | lr:0.010000
# Epoch[4/100] | loss train:0.011544, test:0.000305 | lr:0.010000
# Epoch[5/100] | loss train:0.010502, test:0.003183 | lr:0.010000
# Epoch[6/100] | loss train:0.010987, test:0.006256 | lr:0.010000
# Epoch[7/100] | loss train:0.008546, test:0.000334 | lr:0.010000
# Epoch[8/100] | loss train:0.008758, test:0.003143 | lr:0.010000
# Epoch[9/100] | loss train:0.009522, test:0.008240 | lr:0.010000
# Epoch[10/100] | loss train:0.009349, test:0.012311 | lr:0.010000
# Epoch[11/100] | loss train:0.012098, test:0.000982 | lr:0.010000
# Epoch[12/100] | loss train:0.010748, test:0.000386 | lr:0.010000
# Epoch[13/100] | loss train:0.008666, test:0.000758 | lr:0.010000
# Epoch[14/100] | loss train:0.007572, test:0.001816 | lr:0.010000
# Epoch[15/100] | loss train:0.009771, test:0.000546 | lr:0.010000
# Epoch[16/100] | loss train:0.009341, test:0.000383 | lr:0.010000
# Epoch[17/100] | loss train:0.007808, test:0.002996 | lr:0.010000
# Epoch[18/100] | loss train:0.010206, test:0.000396 | lr:0.010000
# Epoch[19/100] | loss train:0.006842, test:0.002004 | lr:0.010000
# Epoch[20/100] | loss train:0.008203, test:0.000609 | lr:0.010000
# Epoch[21/100] | loss train:0.008333, test:0.001579 | lr:0.010000
# Epoch[22/100] | loss train:0.007238, test:0.001677 | lr:0.010000
# Epoch[23/100] | loss train:0.008191, test:0.002001 | lr:0.010000
# Epoch[24/100] | loss train:0.007383, test:0.000968 | lr:0.010000
# Epoch[25/100] | loss train:0.007143, test:0.001042 | lr:0.010000
# Epoch[26/100] | loss train:0.008272, test:0.002212 | lr:0.010000
# Epoch[27/100] | loss train:0.011004, test:0.000599 | lr:0.010000
# Epoch[28/100] | loss train:0.008236, test:0.000622 | lr:0.010000
# Epoch[29/100] | loss train:0.007233, test:0.000700 | lr:0.010000
# Epoch[30/100] | loss train:0.007687, test:0.002293 | lr:0.010000
# Epoch[31/100] | loss train:0.008827, test:0.003373 | lr:0.010000
# Epoch[32/100] | loss train:0.007763, test:0.001074 | lr:0.010000
# Epoch[33/100] | loss train:0.006896, test:0.000497 | lr:0.010000
# Epoch[34/100] | loss train:0.008976, test:0.001451 | lr:0.010000
# Epoch[35/100] | loss train:0.007412, test:0.000500 | lr:0.010000
# Epoch[36/100] | loss train:0.007336, test:0.000383 | lr:0.010000
# Epoch[37/100] | loss train:0.008971, test:0.000707 | lr:0.010000
# Epoch[38/100] | loss train:0.012378, test:0.000734 | lr:0.010000
# Epoch[39/100] | loss train:0.007028, test:0.001031 | lr:0.010000
# Epoch[40/100] | loss train:0.007863, test:0.000551 | lr:0.010000
# Epoch[41/100] | loss train:0.006224, test:0.000441 | lr:0.001000
# Epoch[42/100] | loss train:0.005690, test:0.000798 | lr:0.001000
# Epoch[43/100] | loss train:0.005656, test:0.000480 | lr:0.001000
# Epoch[44/100] | loss train:0.005450, test:0.000473 | lr:0.001000
# Epoch[45/100] | loss train:0.005254, test:0.000684 | lr:0.001000
# Epoch[46/100] | loss train:0.005460, test:0.000484 | lr:0.001000
# Epoch[47/100] | loss train:0.005223, test:0.000623 | lr:0.001000
# Epoch[48/100] | loss train:0.005913, test:0.000378 | lr:0.001000
# Epoch[49/100] | loss train:0.005498, test:0.000406 | lr:0.001000
# Epoch[50/100] | loss train:0.004933, test:0.000379 | lr:0.001000
# Epoch[51/100] | loss train:0.005648, test:0.000437 | lr:0.001000
# Epoch[52/100] | loss train:0.004999, test:0.000400 | lr:0.001000
# Epoch[53/100] | loss train:0.005080, test:0.000398 | lr:0.001000
# Epoch[54/100] | loss train:0.005060, test:0.000372 | lr:0.001000
# Epoch[55/100] | loss train:0.005593, test:0.000367 | lr:0.001000
# Epoch[56/100] | loss train:0.005600, test:0.000493 | lr:0.001000
# Epoch[57/100] | loss train:0.005398, test:0.000391 | lr:0.001000
# Epoch[58/100] | loss train:0.005247, test:0.000357 | lr:0.001000
# Epoch[59/100] | loss train:0.004734, test:0.000434 | lr:0.001000
# Epoch[60/100] | loss train:0.005192, test:0.000457 | lr:0.001000
# Epoch[61/100] | loss train:0.005869, test:0.000348 | lr:0.001000
# Epoch[62/100] | loss train:0.005621, test:0.000395 | lr:0.001000
# Epoch[63/100] | loss train:0.006490, test:0.000352 | lr:0.001000
# Epoch[64/100] | loss train:0.005237, test:0.000456 | lr:0.001000
# Epoch[65/100] | loss train:0.005448, test:0.000431 | lr:0.001000
# Epoch[66/100] | loss train:0.005944, test:0.000395 | lr:0.001000
# Epoch[67/100] | loss train:0.005210, test:0.000429 | lr:0.001000
# Epoch[68/100] | loss train:0.005132, test:0.000354 | lr:0.001000
# Epoch[69/100] | loss train:0.005211, test:0.000351 | lr:0.001000
# Epoch[70/100] | loss train:0.005773, test:0.000313 | lr:0.001000
# Epoch[71/100] | loss train:0.006020, test:0.000297 | lr:0.001000
# Epoch[72/100] | loss train:0.005909, test:0.000333 | lr:0.001000
# Epoch[73/100] | loss train:0.005410, test:0.000342 | lr:0.001000
# Epoch[74/100] | loss train:0.005046, test:0.000351 | lr:0.001000
# Epoch[75/100] | loss train:0.005232, test:0.000620 | lr:0.001000
# Epoch[76/100] | loss train:0.005882, test:0.000353 | lr:0.001000
# Epoch[77/100] | loss train:0.005043, test:0.000345 | lr:0.001000
# Epoch[78/100] | loss train:0.005186, test:0.000384 | lr:0.001000
# Epoch[79/100] | loss train:0.005783, test:0.000348 | lr:0.001000
# Epoch[80/100] | loss train:0.005190, test:0.000566 | lr:0.001000
# Epoch[81/100] | loss train:0.008117, test:0.000330 | lr:0.000100
# Epoch[82/100] | loss train:0.004885, test:0.000322 | lr:0.000100
# Epoch[83/100] | loss train:0.004723, test:0.000320 | lr:0.000100
# Epoch[84/100] | loss train:0.005244, test:0.000301 | lr:0.000100
# Epoch[85/100] | loss train:0.005206, test:0.000341 | lr:0.000100
# Epoch[86/100] | loss train:0.005917, test:0.000372 | lr:0.000100
# Epoch[87/100] | loss train:0.004930, test:0.000342 | lr:0.000100
# Epoch[88/100] | loss train:0.005932, test:0.000318 | lr:0.000100
# Epoch[89/100] | loss train:0.004570, test:0.000333 | lr:0.000100
# Epoch[90/100] | loss train:0.010676, test:0.000329 | lr:0.000100
# Epoch[91/100] | loss train:0.005506, test:0.000347 | lr:0.000100
# Epoch[92/100] | loss train:0.005318, test:0.000332 | lr:0.000100
# Epoch[93/100] | loss train:0.005159, test:0.000341 | lr:0.000100
# Epoch[94/100] | loss train:0.005239, test:0.000332 | lr:0.000100
# Epoch[95/100] | loss train:0.004832, test:0.000319 | lr:0.000100
# Epoch[96/100] | loss train:0.004772, test:0.000328 | lr:0.000100
# Epoch[97/100] | loss train:0.006770, test:0.000355 | lr:0.000100
# Epoch[98/100] | loss train:0.005832, test:0.000314 | lr:0.000100
# Epoch[99/100] | loss train:0.005879, test:0.000353 | lr:0.000100
# Epoch[100/100] | loss train:0.005055, test:0.000313 | lr:0.000100
# Mean absolute error:  1.6904449043270222
# Root mean squared error:  5.792356210345939
# Epoch[1/100] | loss train:0.054856, test:0.012431 | lr:0.010000
# Epoch[2/100] | loss train:0.014645, test:0.000662 | lr:0.010000
# Epoch[3/100] | loss train:0.010049, test:0.000467 | lr:0.010000
# Epoch[4/100] | loss train:0.010979, test:0.001868 | lr:0.010000
# Epoch[5/100] | loss train:0.008405, test:0.000299 | lr:0.010000
# Epoch[6/100] | loss train:0.008755, test:0.000408 | lr:0.010000
# Epoch[7/100] | loss train:0.009361, test:0.001488 | lr:0.010000
# Epoch[8/100] | loss train:0.009077, test:0.000344 | lr:0.010000
# Epoch[9/100] | loss train:0.010268, test:0.011601 | lr:0.010000
# Epoch[10/100] | loss train:0.009480, test:0.001544 | lr:0.010000
# Epoch[11/100] | loss train:0.009987, test:0.000895 | lr:0.010000
# Epoch[12/100] | loss train:0.008619, test:0.005444 | lr:0.010000
# Epoch[13/100] | loss train:0.008423, test:0.002196 | lr:0.010000
# Epoch[14/100] | loss train:0.010002, test:0.000555 | lr:0.010000
# Epoch[15/100] | loss train:0.007565, test:0.005738 | lr:0.010000
# Epoch[16/100] | loss train:0.009082, test:0.001453 | lr:0.010000
# Epoch[17/100] | loss train:0.008358, test:0.000375 | lr:0.010000
# Epoch[18/100] | loss train:0.008765, test:0.000359 | lr:0.010000
# Epoch[19/100] | loss train:0.007252, test:0.001473 | lr:0.010000
# Epoch[20/100] | loss train:0.008071, test:0.000403 | lr:0.010000
# Epoch[21/100] | loss train:0.010217, test:0.001902 | lr:0.010000
# Epoch[22/100] | loss train:0.008945, test:0.002880 | lr:0.010000
# Epoch[23/100] | loss train:0.008045, test:0.000806 | lr:0.010000
# Epoch[24/100] | loss train:0.009246, test:0.000395 | lr:0.010000
# Epoch[25/100] | loss train:0.007997, test:0.001071 | lr:0.010000
# Epoch[26/100] | loss train:0.007364, test:0.000819 | lr:0.010000
# Epoch[27/100] | loss train:0.008683, test:0.000396 | lr:0.010000
# Epoch[28/100] | loss train:0.007626, test:0.000369 | lr:0.010000
# Epoch[29/100] | loss train:0.019958, test:0.001262 | lr:0.010000
# Epoch[30/100] | loss train:0.008169, test:0.000369 | lr:0.010000
# Epoch[31/100] | loss train:0.007977, test:0.000848 | lr:0.010000
# Epoch[32/100] | loss train:0.006694, test:0.001201 | lr:0.010000
# Epoch[33/100] | loss train:0.008164, test:0.003025 | lr:0.010000
# Epoch[34/100] | loss train:0.007807, test:0.000334 | lr:0.010000
# Epoch[35/100] | loss train:0.007456, test:0.000521 | lr:0.010000
# Epoch[36/100] | loss train:0.008191, test:0.000469 | lr:0.010000
# Epoch[37/100] | loss train:0.007600, test:0.001737 | lr:0.010000
# Epoch[38/100] | loss train:0.007244, test:0.000477 | lr:0.010000
# Epoch[39/100] | loss train:0.008091, test:0.000576 | lr:0.010000
# Epoch[40/100] | loss train:0.008577, test:0.000444 | lr:0.010000
# Epoch[41/100] | loss train:0.005565, test:0.000337 | lr:0.001000
# Epoch[42/100] | loss train:0.006129, test:0.001085 | lr:0.001000
# Epoch[43/100] | loss train:0.006663, test:0.000403 | lr:0.001000
# Epoch[44/100] | loss train:0.005527, test:0.000338 | lr:0.001000
# Epoch[45/100] | loss train:0.005036, test:0.000323 | lr:0.001000
# Epoch[46/100] | loss train:0.005795, test:0.000333 | lr:0.001000
# Epoch[47/100] | loss train:0.005368, test:0.000444 | lr:0.001000
# Epoch[48/100] | loss train:0.005416, test:0.000351 | lr:0.001000
# Epoch[49/100] | loss train:0.005444, test:0.000337 | lr:0.001000
# Epoch[50/100] | loss train:0.005789, test:0.000418 | lr:0.001000
# Epoch[51/100] | loss train:0.005512, test:0.000362 | lr:0.001000
# Epoch[52/100] | loss train:0.006508, test:0.000456 | lr:0.001000
# Epoch[53/100] | loss train:0.005849, test:0.000390 | lr:0.001000
# Epoch[54/100] | loss train:0.006343, test:0.000323 | lr:0.001000
# Epoch[55/100] | loss train:0.005303, test:0.000568 | lr:0.001000
# Epoch[56/100] | loss train:0.006017, test:0.000367 | lr:0.001000
# Epoch[57/100] | loss train:0.005629, test:0.000339 | lr:0.001000
# Epoch[58/100] | loss train:0.005700, test:0.000666 | lr:0.001000
# Epoch[59/100] | loss train:0.005729, test:0.000452 | lr:0.001000
# Epoch[60/100] | loss train:0.005429, test:0.000345 | lr:0.001000
# Epoch[61/100] | loss train:0.005453, test:0.000505 | lr:0.001000
# Epoch[62/100] | loss train:0.005303, test:0.000406 | lr:0.001000
# Epoch[63/100] | loss train:0.005570, test:0.000351 | lr:0.001000
# Epoch[64/100] | loss train:0.005639, test:0.000399 | lr:0.001000
# Epoch[65/100] | loss train:0.005532, test:0.000340 | lr:0.001000
# Epoch[66/100] | loss train:0.005709, test:0.000322 | lr:0.001000
# Epoch[67/100] | loss train:0.005773, test:0.000445 | lr:0.001000
# Epoch[68/100] | loss train:0.006166, test:0.000348 | lr:0.001000
# Epoch[69/100] | loss train:0.008894, test:0.000374 | lr:0.001000
# Epoch[70/100] | loss train:0.005382, test:0.000472 | lr:0.001000
# Epoch[71/100] | loss train:0.007330, test:0.000355 | lr:0.001000
# Epoch[72/100] | loss train:0.005155, test:0.000407 | lr:0.001000
# Epoch[73/100] | loss train:0.005276, test:0.000325 | lr:0.001000
# Epoch[74/100] | loss train:0.005178, test:0.000366 | lr:0.001000
# Epoch[75/100] | loss train:0.005101, test:0.000370 | lr:0.001000
# Epoch[76/100] | loss train:0.005574, test:0.000296 | lr:0.001000
# Epoch[77/100] | loss train:0.006081, test:0.000340 | lr:0.001000
# Epoch[78/100] | loss train:0.005662, test:0.000331 | lr:0.001000
# Epoch[79/100] | loss train:0.005871, test:0.000385 | lr:0.001000
# Epoch[80/100] | loss train:0.005072, test:0.000351 | lr:0.001000
# Epoch[81/100] | loss train:0.005615, test:0.000351 | lr:0.000100
# Epoch[82/100] | loss train:0.005343, test:0.000429 | lr:0.000100
# Epoch[83/100] | loss train:0.004988, test:0.000330 | lr:0.000100
# Epoch[84/100] | loss train:0.005304, test:0.000351 | lr:0.000100
# Epoch[85/100] | loss train:0.005593, test:0.000338 | lr:0.000100
# Epoch[86/100] | loss train:0.005519, test:0.000322 | lr:0.000100
# Epoch[87/100] | loss train:0.007616, test:0.000310 | lr:0.000100
# Epoch[88/100] | loss train:0.005130, test:0.000341 | lr:0.000100
# Epoch[89/100] | loss train:0.005354, test:0.000383 | lr:0.000100
# Epoch[90/100] | loss train:0.005417, test:0.000307 | lr:0.000100
# Epoch[91/100] | loss train:0.005005, test:0.000310 | lr:0.000100
# Epoch[92/100] | loss train:0.005431, test:0.000359 | lr:0.000100
# Epoch[93/100] | loss train:0.004816, test:0.000426 | lr:0.000100
# Epoch[94/100] | loss train:0.005661, test:0.000331 | lr:0.000100
# Epoch[95/100] | loss train:0.005127, test:0.000357 | lr:0.000100
# Epoch[96/100] | loss train:0.005521, test:0.000308 | lr:0.000100
# Epoch[97/100] | loss train:0.005171, test:0.000346 | lr:0.000100
# Epoch[98/100] | loss train:0.005277, test:0.000319 | lr:0.000100
# Epoch[99/100] | loss train:0.004956, test:0.000335 | lr:0.000100
# Epoch[100/100] | loss train:0.004810, test:0.000310 | lr:0.000100
# Mean absolute error:  1.6582938746484461
# Root mean squared error:  5.787979864531934
# Epoch[1/100] | loss train:0.063472, test:0.001462 | lr:0.010000
# Epoch[2/100] | loss train:0.010869, test:0.000747 | lr:0.010000
# Epoch[3/100] | loss train:0.010934, test:0.006193 | lr:0.010000
# Epoch[4/100] | loss train:0.011311, test:0.005253 | lr:0.010000
# Epoch[5/100] | loss train:0.009583, test:0.000309 | lr:0.010000
# Epoch[6/100] | loss train:0.008949, test:0.003615 | lr:0.010000
# Epoch[7/100] | loss train:0.008138, test:0.000405 | lr:0.010000
# Epoch[8/100] | loss train:0.009144, test:0.000363 | lr:0.010000
# Epoch[9/100] | loss train:0.007144, test:0.001495 | lr:0.010000
# Epoch[10/100] | loss train:0.008992, test:0.000599 | lr:0.010000
# Epoch[11/100] | loss train:0.007372, test:0.000861 | lr:0.010000
# Epoch[12/100] | loss train:0.008646, test:0.000839 | lr:0.010000
# Epoch[13/100] | loss train:0.007914, test:0.001627 | lr:0.010000
# Epoch[14/100] | loss train:0.008856, test:0.000467 | lr:0.010000
# Epoch[15/100] | loss train:0.008411, test:0.000395 | lr:0.010000
# Epoch[16/100] | loss train:0.007902, test:0.004637 | lr:0.010000
# Epoch[17/100] | loss train:0.007712, test:0.000491 | lr:0.010000
# Epoch[18/100] | loss train:0.006640, test:0.000687 | lr:0.010000
# Epoch[19/100] | loss train:0.007029, test:0.000415 | lr:0.010000
# Epoch[20/100] | loss train:0.008373, test:0.000409 | lr:0.010000
# Epoch[21/100] | loss train:0.006762, test:0.001368 | lr:0.010000
# Epoch[22/100] | loss train:0.009645, test:0.000712 | lr:0.010000
# Epoch[23/100] | loss train:0.008126, test:0.000977 | lr:0.010000
# Epoch[24/100] | loss train:0.011465, test:0.001216 | lr:0.010000
# Epoch[25/100] | loss train:0.007537, test:0.000799 | lr:0.010000
# Epoch[26/100] | loss train:0.007700, test:0.004985 | lr:0.010000
# Epoch[27/100] | loss train:0.006655, test:0.000685 | lr:0.010000
# Epoch[28/100] | loss train:0.007630, test:0.003324 | lr:0.010000
# Epoch[29/100] | loss train:0.007704, test:0.002601 | lr:0.010000
# Epoch[30/100] | loss train:0.007440, test:0.000361 | lr:0.010000
# ...
# Epoch[59/100] | loss train:0.007204, test:0.000289 | lr:0.001000
# Epoch[60/100] | loss train:0.005976, test:0.000543 | lr:0.001000
# Epoch[61/100] | loss train:0.005254, test:0.000292 | lr:0.001000
# Epoch[62/100] | loss train:0.004814, test:0.000315 | lr:0.001000
# Epoch[63/100] | loss train:0.004865, test:0.000377 | lr:0.001000
# Epoch[64/100] | loss train:0.005074, test:0.000409 | lr:0.001000
# Epoch[65/100] | loss train:0.004904, test:0.000312 | lr:0.001000
# Epoch[66/100] | loss train:0.005433, test:0.000296 | lr:0.001000
# Epoch[67/100] | loss train:0.005356, test:0.000387 | lr:0.001000
# Epoch[68/100] | loss train:0.005123, test:0.000284 | lr:0.001000
# Epoch[69/100] | loss train:0.007825, test:0.000448 | lr:0.001000
# Epoch[70/100] | loss train:0.005473, test:0.000339 | lr:0.001000
# Epoch[71/100] | loss train:0.005394, test:0.000326 | lr:0.001000
# Epoch[72/100] | loss train:0.005643, test:0.000283 | lr:0.001000
# Epoch[73/100] | loss train:0.005237, test:0.000303 | lr:0.001000
# Epoch[74/100] | loss train:0.005201, test:0.000279 | lr:0.001000
# Epoch[75/100] | loss train:0.005011, test:0.000506 | lr:0.001000
# Epoch[76/100] | loss train:0.004916, test:0.000313 | lr:0.001000
# Epoch[77/100] | loss train:0.004697, test:0.000276 | lr:0.001000
# Epoch[78/100] | loss train:0.005320, test:0.000282 | lr:0.001000
# Epoch[79/100] | loss train:0.005063, test:0.000288 | lr:0.001000
# Epoch[80/100] | loss train:0.005135, test:0.000296 | lr:0.001000
# Epoch[81/100] | loss train:0.005248, test:0.000317 | lr:0.000100
# Epoch[82/100] | loss train:0.005078, test:0.000312 | lr:0.000100
# Epoch[83/100] | loss train:0.004885, test:0.000268 | lr:0.000100
# Epoch[84/100] | loss train:0.004802, test:0.000327 | lr:0.000100
# Epoch[85/100] | loss train:0.005052, test:0.000271 | lr:0.000100
# Epoch[86/100] | loss train:0.005068, test:0.000302 | lr:0.000100
# Epoch[87/100] | loss train:0.005093, test:0.000273 | lr:0.000100
# Epoch[88/100] | loss train:0.005039, test:0.000292 | lr:0.000100
# Epoch[89/100] | loss train:0.006458, test:0.000289 | lr:0.000100
# Epoch[90/100] | loss train:0.005683, test:0.000264 | lr:0.000100
# Epoch[91/100] | loss train:0.004762, test:0.000289 | lr:0.000100
# Epoch[92/100] | loss train:0.006068, test:0.000283 | lr:0.000100
# Epoch[93/100] | loss train:0.005109, test:0.000270 | lr:0.000100
# Epoch[94/100] | loss train:0.004576, test:0.000305 | lr:0.000100
# Epoch[95/100] | loss train:0.004996, test:0.000284 | lr:0.000100
# Epoch[96/100] | loss train:0.004960, test:0.000276 | lr:0.000100
# Epoch[97/100] | loss train:0.004792, test:0.000285 | lr:0.000100
# Epoch[98/100] | loss train:0.004866, test:0.000286 | lr:0.000100
# Epoch[99/100] | loss train:0.004817, test:0.000294 | lr:0.000100
# Epoch[100/100] | loss train:0.004875, test:0.000330 | lr:0.000100
# Mean absolute error:  1.728852307524615
# Root mean squared error:  5.804928186112913
# Epoch[1/100] | loss train:0.054900, test:0.001362 | lr:0.010000
# Epoch[2/100] | loss train:0.010220, test:0.001815 | lr:0.010000
# Epoch[3/100] | loss train:0.008786, test:0.001720 | lr:0.010000
# Epoch[4/100] | loss train:0.009555, test:0.002145 | lr:0.010000
# Epoch[5/100] | loss train:0.010103, test:0.000309 | lr:0.010000
# Epoch[6/100] | loss train:0.008979, test:0.002675 | lr:0.010000
# Epoch[7/100] | loss train:0.008055, test:0.000484 | lr:0.010000
# Epoch[8/100] | loss train:0.008738, test:0.000402 | lr:0.010000
# Epoch[9/100] | loss train:0.007129, test:0.006254 | lr:0.010000
# Epoch[10/100] | loss train:0.009571, test:0.004096 | lr:0.010000
# Epoch[11/100] | loss train:0.010280, test:0.000987 | lr:0.010000
# Epoch[12/100] | loss train:0.007879, test:0.000568 | lr:0.010000
# Epoch[13/100] | loss train:0.007927, test:0.003516 | lr:0.010000
# Epoch[14/100] | loss train:0.008262, test:0.001843 | lr:0.010000
# Epoch[15/100] | loss train:0.007410, test:0.002223 | lr:0.010000
# Epoch[16/100] | loss train:0.008091, test:0.000852 | lr:0.010000
# Epoch[17/100] | loss train:0.006957, test:0.001072 | lr:0.010000
# Epoch[18/100] | loss train:0.007509, test:0.000596 | lr:0.010000
# Epoch[19/100] | loss train:0.007876, test:0.002464 | lr:0.010000
# Epoch[20/100] | loss train:0.006828, test:0.003216 | lr:0.010000
# Epoch[21/100] | loss train:0.008920, test:0.000596 | lr:0.010000
# Epoch[22/100] | loss train:0.006390, test:0.006643 | lr:0.010000
# Epoch[23/100] | loss train:0.006930, test:0.000435 | lr:0.010000
# Epoch[24/100] | loss train:0.006550, test:0.002316 | lr:0.010000
# Epoch[25/100] | loss train:0.007492, test:0.000456 | lr:0.010000
# Epoch[26/100] | loss train:0.006463, test:0.000567 | lr:0.010000
# Epoch[27/100] | loss train:0.007499, test:0.000722 | lr:0.010000
# Epoch[28/100] | loss train:0.006008, test:0.000342 | lr:0.010000
# Epoch[29/100] | loss train:0.009284, test:0.000601 | lr:0.010000
# Epoch[30/100] | loss train:0.006578, test:0.000588 | lr:0.010000
# Epoch[31/100] | loss train:0.007620, test:0.000382 | lr:0.010000
# Epoch[32/100] | loss train:0.007811, test:0.000640 | lr:0.010000
# Epoch[33/100] | loss train:0.006994, test:0.000313 | lr:0.010000
# Epoch[34/100] | loss train:0.007005, test:0.002184 | lr:0.010000
# Epoch[35/100] | loss train:0.007551, test:0.000423 | lr:0.010000
# Epoch[36/100] | loss train:0.006480, test:0.000401 | lr:0.010000
# Epoch[37/100] | loss train:0.006977, test:0.000712 | lr:0.010000
# Epoch[38/100] | loss train:0.007626, test:0.001590 | lr:0.010000
# Epoch[39/100] | loss train:0.007548, test:0.001777 | lr:0.010000
# Epoch[40/100] | loss train:0.007596, test:0.000451 | lr:0.010000
# Epoch[41/100] | loss train:0.005558, test:0.000326 | lr:0.001000
# Epoch[42/100] | loss train:0.005225, test:0.000348 | lr:0.001000
# Epoch[43/100] | loss train:0.004896, test:0.000320 | lr:0.001000
# Epoch[44/100] | loss train:0.005227, test:0.000455 | lr:0.001000
# Epoch[45/100] | loss train:0.005225, test:0.000392 | lr:0.001000
# Epoch[46/100] | loss train:0.005311, test:0.000482 | lr:0.001000
# Epoch[47/100] | loss train:0.004784, test:0.000338 | lr:0.001000
# Epoch[48/100] | loss train:0.005776, test:0.000325 | lr:0.001000
# Epoch[49/100] | loss train:0.005005, test:0.000321 | lr:0.001000
# Epoch[50/100] | loss train:0.006464, test:0.000577 | lr:0.001000
# Epoch[51/100] | loss train:0.007579, test:0.000397 | lr:0.001000
# Epoch[52/100] | loss train:0.005076, test:0.000537 | lr:0.001000
# Epoch[53/100] | loss train:0.004721, test:0.000484 | lr:0.001000
# Epoch[54/100] | loss train:0.005407, test:0.000319 | lr:0.001000
# Epoch[55/100] | loss train:0.005182, test:0.000342 | lr:0.001000
# Epoch[56/100] | loss train:0.005090, test:0.000299 | lr:0.001000
# Epoch[57/100] | loss train:0.005105, test:0.000293 | lr:0.001000
# Epoch[58/100] | loss train:0.005322, test:0.000574 | lr:0.001000
# Epoch[59/100] | loss train:0.004863, test:0.000463 | lr:0.001000
# Epoch[60/100] | loss train:0.004813, test:0.000489 | lr:0.001000
# Epoch[61/100] | loss train:0.005019, test:0.000389 | lr:0.001000
# Epoch[62/100] | loss train:0.006507, test:0.000300 | lr:0.001000
# Epoch[63/100] | loss train:0.005594, test:0.000386 | lr:0.001000
# Epoch[64/100] | loss train:0.005069, test:0.000376 | lr:0.001000
# Epoch[65/100] | loss train:0.005716, test:0.000447 | lr:0.001000
# Epoch[66/100] | loss train:0.006227, test:0.000315 | lr:0.001000
# Epoch[67/100] | loss train:0.005347, test:0.000331 | lr:0.001000
# Epoch[68/100] | loss train:0.005050, test:0.000312 | lr:0.001000
# Epoch[69/100] | loss train:0.005351, test:0.000434 | lr:0.001000
# Epoch[70/100] | loss train:0.004566, test:0.000306 | lr:0.001000
# Epoch[71/100] | loss train:0.005384, test:0.000355 | lr:0.001000
# Epoch[72/100] | loss train:0.005000, test:0.000340 | lr:0.001000
# Epoch[73/100] | loss train:0.005117, test:0.000381 | lr:0.001000
# Epoch[74/100] | loss train:0.005224, test:0.000726 | lr:0.001000
# Epoch[75/100] | loss train:0.005178, test:0.000372 | lr:0.001000
# Epoch[76/100] | loss train:0.006376, test:0.000327 | lr:0.001000
# Epoch[77/100] | loss train:0.006103, test:0.000293 | lr:0.001000
# Epoch[78/100] | loss train:0.005282, test:0.000359 | lr:0.001000
# Epoch[79/100] | loss train:0.004968, test:0.000319 | lr:0.001000
# Epoch[80/100] | loss train:0.007450, test:0.000296 | lr:0.001000
# Epoch[81/100] | loss train:0.005071, test:0.000285 | lr:0.000100
# Epoch[82/100] | loss train:0.004610, test:0.000297 | lr:0.000100
# Epoch[83/100] | loss train:0.004722, test:0.000276 | lr:0.000100
# Epoch[84/100] | loss train:0.005042, test:0.000295 | lr:0.000100
# Epoch[85/100] | loss train:0.005000, test:0.000295 | lr:0.000100
# Epoch[86/100] | loss train:0.007523, test:0.000360 | lr:0.000100
# Epoch[87/100] | loss train:0.007086, test:0.000293 | lr:0.000100
# Epoch[88/100] | loss train:0.004967, test:0.000295 | lr:0.000100
# Epoch[89/100] | loss train:0.004986, test:0.000290 | lr:0.000100
# Epoch[90/100] | loss train:0.005130, test:0.000318 | lr:0.000100
# Epoch[91/100] | loss train:0.005049, test:0.000295 | lr:0.000100
# Epoch[92/100] | loss train:0.014080, test:0.000288 | lr:0.000100
# Epoch[93/100] | loss train:0.005213, test:0.000301 | lr:0.000100
# Epoch[94/100] | loss train:0.010918, test:0.000291 | lr:0.000100
# Epoch[95/100] | loss train:0.006018, test:0.000307 | lr:0.000100
# Epoch[96/100] | loss train:0.004674, test:0.000293 | lr:0.000100
# Epoch[97/100] | loss train:0.006027, test:0.000296 | lr:0.000100
# Epoch[98/100] | loss train:0.005178, test:0.000290 | lr:0.000100
# Epoch[99/100] | loss train:0.005124, test:0.000309 | lr:0.000100
# Epoch[100/100] | loss train:0.004356, test:0.000358 | lr:0.000100
# Mean absolute error:  1.681647935572935
# Root mean squared error:  5.782403221674861
# Epoch[1/100] | loss train:0.049593, test:0.001463 | lr:0.010000
# Epoch[2/100] | loss train:0.011587, test:0.004305 | lr:0.010000
# Epoch[3/100] | loss train:0.011746, test:0.000957 | lr:0.010000
# Epoch[4/100] | loss train:0.010597, test:0.001247 | lr:0.010000
# Epoch[5/100] | loss train:0.010996, test:0.000297 | lr:0.010000
# Epoch[6/100] | loss train:0.008318, test:0.001272 | lr:0.010000
# Epoch[7/100] | loss train:0.009035, test:0.000382 | lr:0.010000
# Epoch[8/100] | loss train:0.010082, test:0.002014 | lr:0.010000
# Epoch[9/100] | loss train:0.007851, test:0.004118 | lr:0.010000
# Epoch[10/100] | loss train:0.018693, test:0.001440 | lr:0.010000
# Epoch[11/100] | loss train:0.011684, test:0.000351 | lr:0.010000
# Epoch[12/100] | loss train:0.009934, test:0.002129 | lr:0.010000
# Epoch[13/100] | loss train:0.008845, test:0.000366 | lr:0.010000
# Epoch[14/100] | loss train:0.008604, test:0.002101 | lr:0.010000
# Epoch[15/100] | loss train:0.007946, test:0.000989 | lr:0.010000
# Epoch[16/100] | loss train:0.009016, test:0.000542 | lr:0.010000
# Epoch[17/100] | loss train:0.010280, test:0.000533 | lr:0.010000
# Epoch[18/100] | loss train:0.008797, test:0.003367 | lr:0.010000
# Epoch[19/100] | loss train:0.007882, test:0.001561 | lr:0.010000
# Epoch[20/100] | loss train:0.007037, test:0.000645 | lr:0.010000
# Epoch[21/100] | loss train:0.009055, test:0.003414 | lr:0.010000
# Epoch[22/100] | loss train:0.009863, test:0.001464 | lr:0.010000
# Epoch[23/100] | loss train:0.010103, test:0.001267 | lr:0.010000
# Epoch[24/100] | loss train:0.007347, test:0.000422 | lr:0.010000
# Epoch[25/100] | loss train:0.006846, test:0.000439 | lr:0.010000
# Epoch[26/100] | loss train:0.009073, test:0.001885 | lr:0.010000
# Epoch[27/100] | loss train:0.006933, test:0.005476 | lr:0.010000
# Epoch[28/100] | loss train:0.007734, test:0.000449 | lr:0.010000
# Epoch[29/100] | loss train:0.007464, test:0.004136 | lr:0.010000
# Epoch[30/100] | loss train:0.010519, test:0.000548 | lr:0.010000
# Epoch[31/100] | loss train:0.007360, test:0.000616 | lr:0.010000
# Epoch[32/100] | loss train:0.007789, test:0.000647 | lr:0.010000
# Epoch[33/100] | loss train:0.009051, test:0.000366 | lr:0.010000
# Epoch[34/100] | loss train:0.007601, test:0.000760 | lr:0.010000
# Epoch[35/100] | loss train:0.007630, test:0.000645 | lr:0.010000
# Epoch[36/100] | loss train:0.008438, test:0.000376 | lr:0.010000
# Epoch[37/100] | loss train:0.006654, test:0.002439 | lr:0.010000
# Epoch[38/100] | loss train:0.008499, test:0.002261 | lr:0.010000
# Epoch[39/100] | loss train:0.007682, test:0.000410 | lr:0.010000
# Epoch[40/100] | loss train:0.006712, test:0.000732 | lr:0.010000
# Epoch[41/100] | loss train:0.006827, test:0.000344 | lr:0.001000
# Epoch[42/100] | loss train:0.005355, test:0.000483 | lr:0.001000
# Epoch[43/100] | loss train:0.006427, test:0.000354 | lr:0.001000
# Epoch[44/100] | loss train:0.005280, test:0.000371 | lr:0.001000
# Epoch[45/100] | loss train:0.005213, test:0.000393 | lr:0.001000
# Epoch[46/100] | loss train:0.006774, test:0.000392 | lr:0.001000
# Epoch[47/100] | loss train:0.005133, test:0.000453 | lr:0.001000
# Epoch[48/100] | loss train:0.008782, test:0.000375 | lr:0.001000
# Epoch[49/100] | loss train:0.005100, test:0.000398 | lr:0.001000
# Epoch[50/100] | loss train:0.005415, test:0.000398 | lr:0.001000
# Epoch[51/100] | loss train:0.005269, test:0.000350 | lr:0.001000
# Epoch[52/100] | loss train:0.005153, test:0.000360 | lr:0.001000
# Epoch[53/100] | loss train:0.005311, test:0.000376 | lr:0.001000
# Epoch[54/100] | loss train:0.006035, test:0.000375 | lr:0.001000
# Epoch[55/100] | loss train:0.005313, test:0.000344 | lr:0.001000
# Epoch[56/100] | loss train:0.005705, test:0.000344 | lr:0.001000
# Epoch[57/100] | loss train:0.005191, test:0.000340 | lr:0.001000
# Epoch[58/100] | loss train:0.005279, test:0.000396 | lr:0.001000
# Epoch[59/100] | loss train:0.006109, test:0.000445 | lr:0.001000
# Epoch[60/100] | loss train:0.005817, test:0.000474 | lr:0.001000
# Epoch[61/100] | loss train:0.005577, test:0.000365 | lr:0.001000
# Epoch[62/100] | loss train:0.005863, test:0.000398 | lr:0.001000
# Epoch[63/100] | loss train:0.016573, test:0.000325 | lr:0.001000
# Epoch[64/100] | loss train:0.005284, test:0.000418 | lr:0.001000
# Epoch[65/100] | loss train:0.006055, test:0.000373 | lr:0.001000
# Epoch[66/100] | loss train:0.005524, test:0.000353 | lr:0.001000
# Epoch[67/100] | loss train:0.005038, test:0.000332 | lr:0.001000
# Epoch[68/100] | loss train:0.005415, test:0.000393 | lr:0.001000
# Epoch[69/100] | loss train:0.005529, test:0.000517 | lr:0.001000
# Epoch[70/100] | loss train:0.005370, test:0.000544 | lr:0.001000
# Epoch[71/100] | loss train:0.005222, test:0.000381 | lr:0.001000
# Epoch[72/100] | loss train:0.005106, test:0.000381 | lr:0.001000
# Epoch[73/100] | loss train:0.005616, test:0.000386 | lr:0.001000
# Epoch[74/100] | loss train:0.005313, test:0.000515 | lr:0.001000
# Epoch[75/100] | loss train:0.004766, test:0.000374 | lr:0.001000
# Epoch[76/100] | loss train:0.006224, test:0.000378 | lr:0.001000
# Epoch[77/100] | loss train:0.007916, test:0.000374 | lr:0.001000
# Epoch[78/100] | loss train:0.006690, test:0.000317 | lr:0.001000
# Epoch[79/100] | loss train:0.006405, test:0.000352 | lr:0.001000
# Epoch[80/100] | loss train:0.005450, test:0.000323 | lr:0.001000
# Epoch[81/100] | loss train:0.004906, test:0.000381 | lr:0.000100
# Epoch[82/100] | loss train:0.005041, test:0.000322 | lr:0.000100
# Epoch[83/100] | loss train:0.005439, test:0.000337 | lr:0.000100
# Epoch[84/100] | loss train:0.007724, test:0.000324 | lr:0.000100
# Epoch[85/100] | loss train:0.005452, test:0.000366 | lr:0.000100
# Epoch[86/100] | loss train:0.005110, test:0.000347 | lr:0.000100
# Epoch[87/100] | loss train:0.005775, test:0.000347 | lr:0.000100
# Epoch[88/100] | loss train:0.010677, test:0.000335 | lr:0.000100
# Epoch[89/100] | loss train:0.004943, test:0.000312 | lr:0.000100
# Epoch[90/100] | loss train:0.005321, test:0.000330 | lr:0.000100
# Epoch[91/100] | loss train:0.005110, test:0.000361 | lr:0.000100
# Epoch[92/100] | loss train:0.006779, test:0.000339 | lr:0.000100
# Epoch[93/100] | loss train:0.005228, test:0.000332 | lr:0.000100
# Epoch[94/100] | loss train:0.005183, test:0.000326 | lr:0.000100
# Epoch[95/100] | loss train:0.004909, test:0.000353 | lr:0.000100
# Epoch[96/100] | loss train:0.005063, test:0.000333 | lr:0.000100
# Epoch[97/100] | loss train:0.005620, test:0.000334 | lr:0.000100
# Epoch[98/100] | loss train:0.005407, test:0.000320 | lr:0.000100
# Epoch[99/100] | loss train:0.006224, test:0.000340 | lr:0.000100
# Epoch[100/100] | loss train:0.004877, test:0.000324 | lr:0.000100
# Mean absolute error:  1.7024690095173163
# Root mean squared error:  5.797051524791365

# %%
# Mean absolute error

mean = sum(uni_absolute) / len(uni_absolute)
variance = sum([((x - mean) ** 2) for x in uni_absolute]) / len(uni_absolute)
sd = variance ** 0.5

m, bins, patches = plt.hist(x=uni_absolute, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Univariate Mean Absolute Error, No Early Stop')
maxfreq = m.max()
plt.text(1.75, 4.5, '\u03BC={},\n\n\u03C3={}$'.format(mean,sd))
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# 0.025803660196257103
# (0.0, 10.0)

# %%
# Root mean squared error

mean = sum(uni_root) / len(uni_root)
variance = sum([((x - mean) ** 2) for x in uni_root]) / len(uni_root)
sd = variance ** 0.5

m, bins, patches = plt.hist(x=root, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Univariate Root Mean Squared Error, No Early Stop')
plt.text(1.75, 4.5, '\u03BC={},\n\n\u03C3={}$'.format(mean,sd))
maxfreq = m.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Root mean squared error
# ----> 3 mean = sum(uni_root) / len(uni_root)
#       4 variance = sum([((x - mean) ** 2) for x in uni_root]) / len(uni_root)
#       5 sd = variance ** 0.5
#
# NameError: name 'uni_root' is not defined

# %%
# Univariate Monte Carlo, early stopping

uni_absolute = []
uni_root = []

for i in range(n):
    train_dataloader = DataLoader(train_dataset, batch_size=config["training"]["batch_size"], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=config["training"]["batch_size"], shuffle=True)

    model = LSTMModel(input_size=config["model"]["input_size"], hidden_layer_size=config["model"]["lstm_size"], num_layers=config["model"]["num_lstm_layers"], output_size=1, dropout=config["model"]["dropout"])
    model = model.to(config["training"]["device"])

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=config["training"]["learning_rate"], betas=(0.9, 0.98), eps=1e-9)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=config["training"]["scheduler_step_size"], gamma=0.1)

    best_loss = np.inf
    epochs_no_improve = 0
    n_epochs_stop = stop
    
    for epoch in range(config["training"]["num_epoch"]):
        loss_train, lr_train = run_epoch(train_dataloader, is_training=True)
        loss_val, lr_val = run_epoch(val_dataloader)
        scheduler.step()

        print('Epoch[{}/{}] | loss train:{:.6f}, test:{:.6f} | lr:{:.6f}'
                  .format(epoch+1, config["training"]["num_epoch"], loss_train, loss_val, lr_train))
        
        if loss_val < best_loss:
            best_loss = loss_val
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        if epochs_no_improve == n_epochs_stop:
            print("Early stopping.")
            break
        
    train_dataloader = DataLoader(train_dataset, batch_size=config["training"]["batch_size"], shuffle=False)
    val_dataloader = DataLoader(val_dataset, batch_size=config["training"]["batch_size"], shuffle=False)

    model.eval()
    
    predicted_train = np.array([])

    for idx, (x, y) in enumerate(train_dataloader):
        x = x.to(config["training"]["device"])
        out = model(x)
        out = out.cpu().detach().numpy()
        predicted_train = np.concatenate((predicted_train, out))

    predicted_val = np.array([])

    for idx, (x, y) in enumerate(val_dataloader):
        x = x.to(config["training"]["device"])
        out = model(x)
        out = out.cpu().detach().numpy()
        predicted_val = np.concatenate((predicted_val, out))

    data_y_train_pred = np.zeros(num_data_points)
    data_y_val_pred = np.zeros(num_data_points)

    data_y_train_pred[config["data"]["window_size"]:split_index+config["data"]["window_size"]] = scaler.inverse_transform(predicted_train)
    data_y_val_pred[split_index+config["data"]["window_size"]:] = scaler.inverse_transform(predicted_val)

    mae = mean_absolute_error(close_price_data, data_y_train_pred + data_y_val_pred)
    print("Mean absolute error: ", mae)

    rmse = np.sqrt(mean_squared_error(close_price_data, data_y_train_pred+data_y_val_pred))
    print("Root mean squared error: ", rmse)
    
    uni_absolute.append(mae)
    uni_root.append(rmse)
# Out:
# Epoch[1/100] | loss train:0.060890, test:0.005255 | lr:0.010000
# Epoch[2/100] | loss train:0.012653, test:0.001939 | lr:0.010000
# Epoch[3/100] | loss train:0.010072, test:0.005123 | lr:0.010000
# Epoch[4/100] | loss train:0.012555, test:0.000566 | lr:0.010000
# Epoch[5/100] | loss train:0.010102, test:0.002951 | lr:0.010000
# Epoch[6/100] | loss train:0.008543, test:0.000434 | lr:0.010000
# Epoch[7/100] | loss train:0.009091, test:0.001590 | lr:0.010000
# Epoch[8/100] | loss train:0.007999, test:0.000321 | lr:0.010000
# Epoch[9/100] | loss train:0.009513, test:0.003428 | lr:0.010000
# Epoch[10/100] | loss train:0.008704, test:0.000298 | lr:0.010000
# Epoch[11/100] | loss train:0.008429, test:0.002392 | lr:0.010000
# Epoch[12/100] | loss train:0.008205, test:0.001983 | lr:0.010000
# Epoch[13/100] | loss train:0.009265, test:0.001000 | lr:0.010000
# Epoch[14/100] | loss train:0.014542, test:0.001825 | lr:0.010000
# Epoch[15/100] | loss train:0.025169, test:0.003877 | lr:0.010000
# Epoch[16/100] | loss train:0.011644, test:0.001308 | lr:0.010000
# Epoch[17/100] | loss train:0.006687, test:0.000436 | lr:0.010000
# Epoch[18/100] | loss train:0.006512, test:0.004234 | lr:0.010000
# Epoch[19/100] | loss train:0.008672, test:0.001409 | lr:0.010000
# Epoch[20/100] | loss train:0.007712, test:0.002823 | lr:0.010000
# Early stopping.
# Mean absolute error:  7.0688128669840475
# Root mean squared error:  10.972197396552039
# Epoch[1/100] | loss train:0.055464, test:0.001439 | lr:0.010000
# Epoch[2/100] | loss train:0.014016, test:0.000786 | lr:0.010000
# Epoch[3/100] | loss train:0.010352, test:0.002053 | lr:0.010000
# Epoch[4/100] | loss train:0.011657, test:0.000841 | lr:0.010000
# Epoch[5/100] | loss train:0.010425, test:0.002911 | lr:0.010000
# Epoch[6/100] | loss train:0.009801, test:0.000807 | lr:0.010000
# Epoch[7/100] | loss train:0.009611, test:0.002364 | lr:0.010000
# Epoch[8/100] | loss train:0.008016, test:0.000472 | lr:0.010000
# Epoch[9/100] | loss train:0.009565, test:0.000892 | lr:0.010000
# Epoch[10/100] | loss train:0.011887, test:0.004286 | lr:0.010000
# Epoch[11/100] | loss train:0.009310, test:0.001702 | lr:0.010000
# Epoch[12/100] | loss train:0.007922, test:0.000609 | lr:0.010000
# Epoch[13/100] | loss train:0.008764, test:0.003354 | lr:0.010000
# Epoch[14/100] | loss train:0.009024, test:0.000531 | lr:0.010000
# Epoch[15/100] | loss train:0.008277, test:0.000814 | lr:0.010000
# Epoch[16/100] | loss train:0.008542, test:0.000377 | lr:0.010000
# Epoch[17/100] | loss train:0.007663, test:0.001404 | lr:0.010000
# Epoch[18/100] | loss train:0.007331, test:0.000302 | lr:0.010000
# Epoch[19/100] | loss train:0.007274, test:0.000429 | lr:0.010000
# Epoch[20/100] | loss train:0.007310, test:0.000788 | lr:0.010000
# Epoch[21/100] | loss train:0.008611, test:0.000407 | lr:0.010000
# Epoch[22/100] | loss train:0.006639, test:0.000692 | lr:0.010000
# Epoch[23/100] | loss train:0.007753, test:0.000385 | lr:0.010000
# Epoch[24/100] | loss train:0.009691, test:0.002763 | lr:0.010000
# Epoch[25/100] | loss train:0.008091, test:0.000870 | lr:0.010000
# Epoch[26/100] | loss train:0.006601, test:0.000588 | lr:0.010000
# Epoch[27/100] | loss train:0.006952, test:0.000928 | lr:0.010000
# Epoch[28/100] | loss train:0.008925, test:0.000387 | lr:0.010000
# Early stopping.
# Mean absolute error:  2.4093908835846953
# Root mean squared error:  6.2152886202975886
# Epoch[1/100] | loss train:0.056175, test:0.001610 | lr:0.010000
# Epoch[2/100] | loss train:0.012431, test:0.000335 | lr:0.010000
# Epoch[3/100] | loss train:0.010651, test:0.000534 | lr:0.010000
# Epoch[4/100] | loss train:0.022861, test:0.003016 | lr:0.010000
# Epoch[5/100] | loss train:0.010971, test:0.000870 | lr:0.010000
# Epoch[6/100] | loss train:0.008962, test:0.000440 | lr:0.010000
# Epoch[7/100] | loss train:0.009675, test:0.007099 | lr:0.010000
# Epoch[8/100] | loss train:0.008881, test:0.012034 | lr:0.010000
# Epoch[9/100] | loss train:0.014624, test:0.001111 | lr:0.010000
# Epoch[10/100] | loss train:0.008686, test:0.002229 | lr:0.010000
# Epoch[11/100] | loss train:0.008608, test:0.003994 | lr:0.010000
# Epoch[12/100] | loss train:0.009972, test:0.001665 | lr:0.010000
# Early stopping.
# Mean absolute error:  3.6334852536810107
# Root mean squared error:  7.913109322533331
# Epoch[1/100] | loss train:0.044846, test:0.006919 | lr:0.010000
# Epoch[2/100] | loss train:0.014789, test:0.005720 | lr:0.010000
# Epoch[3/100] | loss train:0.011112, test:0.008361 | lr:0.010000
# Epoch[4/100] | loss train:0.009431, test:0.006697 | lr:0.010000
# Epoch[5/100] | loss train:0.012049, test:0.000784 | lr:0.010000
# Epoch[6/100] | loss train:0.008442, test:0.002099 | lr:0.010000
# Epoch[7/100] | loss train:0.008694, test:0.000568 | lr:0.010000
# Epoch[8/100] | loss train:0.009357, test:0.001831 | lr:0.010000
# Epoch[9/100] | loss train:0.009746, test:0.000333 | lr:0.010000
# Epoch[10/100] | loss train:0.008205, test:0.001130 | lr:0.010000
# Epoch[11/100] | loss train:0.007377, test:0.000398 | lr:0.010000
# Epoch[12/100] | loss train:0.008215, test:0.000478 | lr:0.010000
# Epoch[13/100] | loss train:0.009394, test:0.000814 | lr:0.010000
# Epoch[14/100] | loss train:0.010395, test:0.002582 | lr:0.010000
# Epoch[15/100] | loss train:0.008730, test:0.000335 | lr:0.010000
# Epoch[16/100] | loss train:0.007142, test:0.008487 | lr:0.010000
# Epoch[17/100] | loss train:0.009577, test:0.000413 | lr:0.010000
# Epoch[18/100] | loss train:0.008544, test:0.001567 | lr:0.010000
# Epoch[19/100] | loss train:0.007603, test:0.000848 | lr:0.010000
# Early stopping.
# Mean absolute error:  2.3212726850476857
# Root mean squared error:  6.343857650052246
# Epoch[1/100] | loss train:0.057898, test:0.002474 | lr:0.010000
# Epoch[2/100] | loss train:0.013260, test:0.002317 | lr:0.010000
# Epoch[3/100] | loss train:0.011702, test:0.005982 | lr:0.010000
# Epoch[4/100] | loss train:0.017726, test:0.003160 | lr:0.010000
# Epoch[5/100] | loss train:0.010204, test:0.000371 | lr:0.010000
# Epoch[6/100] | loss train:0.009281, test:0.012267 | lr:0.010000
# Epoch[7/100] | loss train:0.011625, test:0.012725 | lr:0.010000
# Epoch[8/100] | loss train:0.009539, test:0.001236 | lr:0.010000
# Epoch[9/100] | loss train:0.007607, test:0.009585 | lr:0.010000
# Epoch[10/100] | loss train:0.009646, test:0.002608 | lr:0.010000
# Epoch[11/100] | loss train:0.010233, test:0.001661 | lr:0.010000
# Epoch[12/100] | loss train:0.013338, test:0.004801 | lr:0.010000
# Epoch[13/100] | loss train:0.008855, test:0.000388 | lr:0.010000
# Epoch[14/100] | loss train:0.007700, test:0.001460 | lr:0.010000
# Epoch[15/100] | loss train:0.009300, test:0.002163 | lr:0.010000
# Early stopping.
# Mean absolute error:  4.568005797101844
# Root mean squared error:  8.457949995065563
# Epoch[1/100] | loss train:0.048688, test:0.001369 | lr:0.010000
# Epoch[2/100] | loss train:0.010165, test:0.000313 | lr:0.010000
# Epoch[3/100] | loss train:0.009642, test:0.000819 | lr:0.010000
# Epoch[4/100] | loss train:0.010077, test:0.001123 | lr:0.010000
# Epoch[5/100] | loss train:0.009668, test:0.001175 | lr:0.010000
# Epoch[6/100] | loss train:0.008334, test:0.000952 | lr:0.010000
# Epoch[7/100] | loss train:0.009183, test:0.000454 | lr:0.010000
# Epoch[8/100] | loss train:0.009885, test:0.000394 | lr:0.010000
# Epoch[9/100] | loss train:0.008254, test:0.001533 | lr:0.010000
# Epoch[10/100] | loss train:0.007476, test:0.000543 | lr:0.010000
# Epoch[11/100] | loss train:0.007471, test:0.003028 | lr:0.010000
# Epoch[12/100] | loss train:0.010190, test:0.004761 | lr:0.010000
# Early stopping.
# Mean absolute error:  5.741967900414358
# Root mean squared error:  10.497601298746005
# Epoch[1/100] | loss train:0.052916, test:0.000832 | lr:0.010000
# Epoch[2/100] | loss train:0.011853, test:0.002851 | lr:0.010000
# Epoch[3/100] | loss train:0.009127, test:0.001811 | lr:0.010000
# Epoch[4/100] | loss train:0.009532, test:0.000853 | lr:0.010000
# Epoch[5/100] | loss train:0.007571, test:0.004350 | lr:0.010000
# Epoch[6/100] | loss train:0.015678, test:0.000422 | lr:0.010000
# Epoch[7/100] | loss train:0.008873, test:0.000992 | lr:0.010000
# Epoch[8/100] | loss train:0.008430, test:0.000355 | lr:0.010000
# Epoch[9/100] | loss train:0.007084, test:0.000844 | lr:0.010000
# Epoch[10/100] | loss train:0.007666, test:0.002275 | lr:0.010000
# Epoch[11/100] | loss train:0.008339, test:0.000382 | lr:0.010000
# Epoch[12/100] | loss train:0.008617, test:0.001308 | lr:0.010000
# Epoch[13/100] | loss train:0.009441, test:0.000636 | lr:0.010000
# Epoch[14/100] | loss train:0.008476, test:0.000418 | lr:0.010000
# Epoch[15/100] | loss train:0.008506, test:0.001276 | lr:0.010000
# Epoch[16/100] | loss train:0.007584, test:0.002384 | lr:0.010000
# Epoch[17/100] | loss train:0.009669, test:0.000431 | lr:0.010000
# Epoch[18/100] | loss train:0.008434, test:0.004652 | lr:0.010000
# Early stopping.
# Mean absolute error:  5.929367183159346
# Root mean squared error:  10.486239576567247
# Epoch[1/100] | loss train:0.052430, test:0.000392 | lr:0.010000
# Epoch[2/100] | loss train:0.011645, test:0.003384 | lr:0.010000
# Epoch[3/100] | loss train:0.011183, test:0.000326 | lr:0.010000
# Epoch[4/100] | loss train:0.014596, test:0.004405 | lr:0.010000
# Epoch[5/100] | loss train:0.010159, test:0.002049 | lr:0.010000
# Epoch[6/100] | loss train:0.008027, test:0.002822 | lr:0.010000
# Epoch[7/100] | loss train:0.009288, test:0.000360 | lr:0.010000
# Epoch[8/100] | loss train:0.009490, test:0.000284 | lr:0.010000
# Epoch[9/100] | loss train:0.009692, test:0.000584 | lr:0.010000
# Epoch[10/100] | loss train:0.009904, test:0.000658 | lr:0.010000
# Epoch[11/100] | loss train:0.008532, test:0.001075 | lr:0.010000
# Epoch[12/100] | loss train:0.007653, test:0.000437 | lr:0.010000
# Epoch[13/100] | loss train:0.007908, test:0.000704 | lr:0.010000
# Epoch[14/100] | loss train:0.007315, test:0.000963 | lr:0.010000
# Epoch[15/100] | loss train:0.007872, test:0.000956 | lr:0.010000
# Epoch[16/100] | loss train:0.007366, test:0.000463 | lr:0.010000
# Epoch[17/100] | loss train:0.007480, test:0.005247 | lr:0.010000
# Epoch[18/100] | loss train:0.009371, test:0.000717 | lr:0.010000
# Early stopping.
# Mean absolute error:  3.8807974879801
# Root mean squared error:  6.984387341306617
# Epoch[1/100] | loss train:0.044362, test:0.006052 | lr:0.010000
# Epoch[2/100] | loss train:0.010553, test:0.001209 | lr:0.010000
# Epoch[3/100] | loss train:0.009453, test:0.000276 | lr:0.010000
# Epoch[4/100] | loss train:0.009095, test:0.000458 | lr:0.010000
# Epoch[5/100] | loss train:0.009703, test:0.001294 | lr:0.010000
# Epoch[6/100] | loss train:0.009937, test:0.000522 | lr:0.010000
# Epoch[7/100] | loss train:0.008568, test:0.000596 | lr:0.010000
# Epoch[8/100] | loss train:0.008693, test:0.000669 | lr:0.010000
# Epoch[9/100] | loss train:0.007727, test:0.000671 | lr:0.010000
# Epoch[10/100] | loss train:0.008074, test:0.002469 | lr:0.010000
# Epoch[11/100] | loss train:0.007700, test:0.001220 | lr:0.010000
# Epoch[12/100] | loss train:0.008554, test:0.001149 | lr:0.010000
# Epoch[13/100] | loss train:0.009684, test:0.000497 | lr:0.010000
# Early stopping.
# Mean absolute error:  2.149154983164009
# Root mean squared error:  6.153938027440019
# Epoch[1/100] | loss train:0.057798, test:0.000389 | lr:0.010000
# Epoch[2/100] | loss train:0.011922, test:0.000801 | lr:0.010000
# Epoch[3/100] | loss train:0.009361, test:0.001191 | lr:0.010000
# Epoch[4/100] | loss train:0.009735, test:0.000289 | lr:0.010000
# Epoch[5/100] | loss train:0.009819, test:0.011592 | lr:0.010000
# Epoch[6/100] | loss train:0.010302, test:0.001014 | lr:0.010000
# Epoch[7/100] | loss train:0.007541, test:0.000514 | lr:0.010000
# Epoch[8/100] | loss train:0.010953, test:0.009936 | lr:0.010000
# Epoch[9/100] | loss train:0.010911, test:0.002489 | lr:0.010000
# Epoch[10/100] | loss train:0.008647, test:0.000993 | lr:0.010000
# Epoch[11/100] | loss train:0.008381, test:0.001119 | lr:0.010000
# Epoch[12/100] | loss train:0.009398, test:0.004642 | lr:0.010000
# Epoch[13/100] | loss train:0.009287, test:0.001616 | lr:0.010000
# Epoch[14/100] | loss train:0.009741, test:0.000360 | lr:0.010000
# Early stopping.
# Mean absolute error:  5.171336890572925
# Root mean squared error:  7.614682353579852

# %%
# Mean absolute error

mean = sum(uni_absolute) / len(uni_absolute)
variance = sum([((x - mean) ** 2) for x in uni_absolute]) / len(uni_absolute)
sd = variance ** 0.5

m, bins, patches = plt.hist(x=uni_absolute, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Univariate Mean Absolute Error, Early Stop')
maxfreq = m.max()
plt.text(1.75, 4.5, '\u03BC={},\n\n\u03C3={}$'.format(mean,sd))
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 10.0)

# %%
# Root mean squared error

mean = sum(uni_root) / len(uni_root)
variance = sum([((x - mean) ** 2) for x in uni_root]) / len(uni_root)
sd = variance ** 0.5

m, bins, patches = plt.hist(x=uni_root, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Univariate Root Mean Squared Error, Early Stop')
plt.text(1.75, 4.5, '\u03BC={},\n\n\u03C3={}'.format(mean,sd))
maxfreq = m.max()
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# ### Multivariate Model

# %%
# prep the data

train_df, test_df = preprocess.prep_data(df=data, split_index = split_index, plot_df=True)
train_df.shape, test_df.shape
# Out:
# Starting with data preparation...
# Completed.
# ((5573, 7), (314, 7))

# %%
sequence_length = 30
batch_size = config["training"]["batch_size"]
n_epochs = config["training"]["num_epoch"]
n_epochs_stop = stop
label_name = 'Close'

# %%
# Multivariate Monte Carlo, no early stopping

multi_absolute = []
multi_root = []
for i in range(10):
    
    hist = train.train_model_no_early(train_df, test_df, label_name, sequence_length, batch_size, n_epochs)
    predictions_descaled, labels_descaled = inference.predict(df=test_df,
                                                          label_name='Close',
                                                          sequence_length=sequence_length)
    mae, rmse = inference.return_loss_metrics(labels_descaled, predictions_descaled)
    multi_absolute.append(mae)
    multi_root.append(rmse)
# Out:
# Starting with model training...
# Epoch 1 train loss: 0.0099 test loss: 0.0053
# Epoch 2 train loss: 0.0629 test loss: 0.0004
# Epoch 3 train loss: 0.08 test loss: 0.0004
# Epoch 4 train loss: 0.078 test loss: 0.0052
# Epoch 5 train loss: 0.0239 test loss: 0.001
# Epoch 6 train loss: 0.0046 test loss: 0.0002
# Epoch 7 train loss: 0.0036 test loss: 0.0001
# Epoch 8 train loss: 0.0032 test loss: 0.0003
# Epoch 9 train loss: 0.003 test loss: 0.0003
# Epoch 10 train loss: 0.0035 test loss: 0.0024
# Epoch 11 train loss: 0.0029 test loss: 0.0003
# Epoch 12 train loss: 0.0019 test loss: 0.0004
# Epoch 13 train loss: 0.0017 test loss: 0.0002
# Epoch 14 train loss: 0.0062 test loss: 0.0003
# Epoch 15 train loss: 0.0024 test loss: 0.0004
# Epoch 16 train loss: 0.0027 test loss: 0.0003
# Epoch 17 train loss: 0.0017 test loss: 0.0004
# Epoch 18 train loss: 0.0032 test loss: 0.0004
# Epoch 19 train loss: 0.0017 test loss: 0.0002
# Epoch 20 train loss: 0.0025 test loss: 0.0005
# Epoch 21 train loss: 0.0016 test loss: 0.0001
# Epoch 22 train loss: 0.0024 test loss: 0.0003
# Epoch 23 train loss: 0.0012 test loss: 0.0002
# Epoch 24 train loss: 0.0016 test loss: 0.0001
# Epoch 25 train loss: 0.0015 test loss: 0.0002
# Epoch 26 train loss: 0.0013 test loss: 0.0004
# Epoch 27 train loss: 0.0013 test loss: 0.0003
# Epoch 28 train loss: 0.0019 test loss: 0.0001
# Epoch 29 train loss: 0.0015 test loss: 0.0001
# Epoch 30 train loss: 0.0013 test loss: 0.0004
# Epoch 31 train loss: 0.0012 test loss: 0.0003
# Epoch 32 train loss: 0.0016 test loss: 0.0002
# Epoch 33 train loss: 0.0014 test loss: 0.0001
# Epoch 34 train loss: 0.0014 test loss: 0.0001
# Epoch 35 train loss: 0.0014 test loss: 0.0002
# Epoch 36 train loss: 0.0014 test loss: 0.0003
# Epoch 37 train loss: 0.0015 test loss: 0.0003
# Epoch 38 train loss: 0.0021 test loss: 0.0003
# Epoch 39 train loss: 0.0026 test loss: 0.0012
# Epoch 40 train loss: 0.0019 test loss: 0.0016

# %%
# Mean absolute error, no early stop

mean = sum(multi_absolute) / len(multi_absolute)
variance = sum([((x - mean) ** 2) for x in multi_absolute]) / len(multi_absolute)
sd = variance ** 0.5

m, bins, patches = plt.hist(x=multi_absolute, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Multivariate Mean Absolute Error, No Early Stop')
maxfreq = m.max()
plt.text(1.75, 4.5, '\u03BC={},\n\n\u03C3={}$'.format(mean,sd))
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)

# %%
# Root mean squared error, no early stop

mean = sum(multi_root) / len(multi_root)
variance = sum([((x - mean) ** 2) for x in multi_root]) / len(multi_root)
sd = variance ** 0.5

m, bins, patches = plt.hist(x=multi_root, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Univariate Root Mean Squared Error, No Early Stop')
plt.text(1.75, 4.5, '\u03BC={},\n\n\u03C3={}'.format(mean,sd))
maxfreq = m.max()
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)

# %%
# Multivariate Monte Carlo, early stopping

multi_absolute = []
multi_root = []
for i in range(10):
    
    hist = train.train_model(train_df, test_df, label_name, sequence_length, batch_size, n_epochs, n_epochs_stop)
    predictions_descaled, labels_descaled = inference.predict(df=test_df,
                                                          label_name='Close',
                                                          sequence_length=sequence_length)
    mae, rmse = inference.get_loss_metrics(labels_descaled, predictions_descaled)
    multi_absolute.append(mae)
    multi_root.append(rmse)

# %%
# Mean absolute error, early stop

mean = sum(multi_absolute) / len(multi_absolute)
variance = sum([((x - mean) ** 2) for x in multi_absolute]) / len(multi_absolute)
sd = variance ** 0.5

m, bins, patches = plt.hist(x=multi_absolute, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Multivariate Mean Absolute Error, Early Stop')
maxfreq = m.max()
plt.text(1.75, 4.5, '\u03BC={},\n\n\u03C3={}$'.format(mean,sd))
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
