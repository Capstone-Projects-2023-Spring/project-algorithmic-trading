# %% [markdown]
# The Alpha Vantage API key is 2JMCN347HZ3BU9RC

# %%
import requests
import pandas as pd

# %%
url = 'https://www.alphavantage.co/query?function=OVERVIEW&symbol=MSFT&apikey=2JMCN347HZ3BU9RC'
r = requests.get(url)
msft = r.json()
msft
# Out:
# {'Symbol': 'MSFT',
#  'AssetType': 'Common Stock',
#  'Name': 'Microsoft Corporation',
#  'Description': "Microsoft Corporation is an American multinational technology company which produces computer software, consumer electronics, personal computers, and related services. Its best known software products are the Microsoft Windows line of operating systems, the Microsoft Office suite, and the Internet Explorer and Edge web browsers. Its flagship hardware products are the Xbox video game consoles and the Microsoft Surface lineup of touchscreen personal computers. Microsoft ranked No. 21 in the 2020 Fortune 500 rankings of the largest United States corporations by total revenue; it was the world's largest software maker by revenue as of 2016. It is considered one of the Big Five companies in the U.S. information technology industry, along with Google, Apple, Amazon, and Facebook.",
#  'CIK': '789019',
#  'Exchange': 'NASDAQ',
#  'Currency': 'USD',
#  'Country': 'USA',
# ...

# %%
microsoft = pd.DataFrame.from_dict(msft,orient="index")
#microsoft = microsoft.transpose()
microsoft
# Out:
#                                                                             0
# Symbol                                                                   MSFT
# AssetType                                                        Common Stock
# Name                                                    Microsoft Corporation
# Description                 Microsoft Corporation is an American multinati...
# CIK                                                                    789019
# Exchange                                                               NASDAQ
# Currency                                                                  USD
# Country                                                                   USA
# Sector                                                             TECHNOLOGY
# Industry                                        SERVICES-PREPACKAGED SOFTWARE
# Address                                    ONE MICROSOFT WAY, REDMOND, WA, US
# ...

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=msft&apikey=2JMCN347HZ3BU9RC'
r = requests.get(url)
msft_monthly = r.json()
msft_monthly
#microsoft_monthly = pd.DataFrame.from_dict(msft_monthly,orient="index")
#microsoft_monthly
# Out:
# {'Meta Data': {'1. Information': 'Monthly Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'msft',
#   '3. Last Refreshed': '2023-02-23',
#   '4. Time Zone': 'US/Eastern'},
#  'Monthly Time Series': {'2023-02-23': {'1. open': '248.0000',
#    '2. high': '276.7600',
#    '3. low': '245.4700',
#    '4. close': '254.7700',
#    '5. volume': '546868881'},
#   '2023-01-31': {'1. open': '243.0800',
#    '2. high': '249.8300',
#    '3. low': '219.3500',
#    '4. close': '247.8100',
#    '5. volume': '666168068'},
#   '2022-12-30': {'1. open': '253.8700',
#    '2. high': '263.9150',
#    '3. low': '233.8700',
#    '4. close': '239.8200',
#    '5. volume': '591366468'},
#   '2022-11-30': {'1. open': '234.6000',
#    '2. high': '255.3300',
#    '3. low': '213.4310',
#    '4. close': '255.1400',
#    '5. volume': '615328220'},
#   '2022-10-31': {'1. open': '235.4100',
#    '2. high': '251.0400',
#    '3. low': '219.1300',
#    '4. close': '232.1300',
# ...

# %% [markdown]
# We still potentially need
#
# flow
#
# hedge fund ownership

# %% [markdown]
# When we backtest we want to use the return, Sharpe ratio, and maximum drawdown to analyze how successful our model is.

# %%
pip install alpha_vantage
# Out:
# ...
#
# ...
#      -------------------------------------- 317.2/317.2 kB 9.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB ? eta 0:00:00
# ...

# %%
from alpha_vantage.timeseries import TimeSeries

# %%
KEY = '2JMCN347HZ3BU9RC'
ts = TimeSeries(key=KEY, output_format='pandas')
df_spy_data, meta_data = ts.get_daily_adjusted(symbol='SPY', outputsize='full')
df_spy_data
# Out:
#                1. open     2. high      3. low    4. close  5. adjusted close  \
# date
# 2023-02-23  401.560000  402.200000  396.250000  400.660000         400.660000
# 2023-02-22  399.520000  401.130000  397.020000  398.540000         398.540000
# 2023-02-21  403.060000  404.160000  398.820000  399.090000         399.090000
# 2023-02-17  406.060000  407.510000  404.050000  407.260000         407.260000
# 2023-02-16  408.790000  412.910000  408.140000  408.280000         408.280000
# ...                ...         ...         ...         ...                ...
# 1999-11-05  138.625000  139.109299  136.781204  137.875000          90.068563
# 1999-11-04  136.750000  137.359299  135.765594  136.531204          89.190712
# 1999-11-03  136.000000  136.375000  135.125000  135.500000          88.517065
# 1999-11-02  135.968704  137.250000  134.593704  134.593704          87.925016
# 1999-11-01  136.500000  137.000000  135.562500  135.562500          88.557894
#
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.6/7.6 MB 13.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 163.0/163.0 kB 9.5 MB/s eta 0:00:00
# ...
#      ------------------------------------- 965.4/965.4 kB 12.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.4/55.4 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 15.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.DataFrame({'SPX': df_spx_data['5. adjusted close']})
df
# Out:
#                    SPX
# date
# 2023-02-23  400.660000
# 2023-02-22  398.540000
# 2023-02-21  399.090000
# 2023-02-17  407.260000
# 2023-02-16  408.280000
# ...                ...
# 1999-11-05   90.068563
# 1999-11-04   89.190712
# 1999-11-03   88.517065
# 1999-11-02   87.925016
# 1999-11-01   88.557894
#
# [5866 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (12, 8))
 
ax_spx = df['SPX'].plot()
plt.show()

# %%
df.to_csv('SPY Data.csv',date_format='%Y%m%d')
